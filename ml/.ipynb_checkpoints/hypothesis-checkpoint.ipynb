# %%
from scipy.stats import ttest_ind
from scipy import stats
import pandas as pd
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %matplotlib inline
import pandas as pd
import numpy as np
import statistics
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics
pd.options.display.float_format = '{:,.5f}'.format

# %%
df = pd.read_csv(r'C:\Users\aaron\prem_league_analytics\ml\fifa_all.csv', index_col=0, low_memory = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-b2ab5e4dc6c8> in <module>
# ----> 1 df = pd.read_csv(r'C:\Users\aaron\prem_league_analytics\ml\fifa_all.csv', index_col=0, low_memory = False)
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\envs\datascience\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1904         kwds["usecols"] = self.usecols
#    1905
# -> 1906         self._reader = parsers.TextReader(src, **kwds)
#    1907         self.unnamed_cols = self._reader.unnamed_cols
#    1908
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'C:\\Users\\aaron\\prem_league_analytics\\ml\\fifa_all.csv' does not exist: b'C:\\Users\\aaron\\prem_league_analytics\\ml\\fifa_all.csv'

# %%
df_pca = df[['pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'value_eur', 'short_name','club']]
df_pca = df_pca[df_pca.value_eur != 0]

# %%
ax = sns.scatterplot(x="value_eur", y="pc1", data=df_pca)

# %%
pc1 = df_pca['pc1']
pc2 = df_pca['pc2']
value_eur = df_pca['value_eur']
value_log_eur = np.log(value_eur)

pc1_mean = np.mean(pc1)
value_mean = np.mean(value_log_eur)
print("pc1 mean value:",pc1_mean)
print("value mean value:",value_mean)
pc1_std = np.std(pc1)
value_std = np.std(value)
print("pc1 std value:",pc1_std)
print("value std value:",value_std)
# Out:
# pc1 mean value: 0.5192199589208788
# value mean value: 13.21813785602699
# pc1 std value: 3.8246707859307065
# value std value: 4310551.402290425

# %%
ttest,pval = ttest_ind(pc1,value_log_eur)
print("p-value", pval)
if pval <0.05:
  print("we reject null hypothesis")
else:
  print("we accept null hypothesis")
# Out:
# p-value 0.0
# we reject null hypothesis

# %%
print("Population Mean: "+str(df_pca['value_eur'].mean()))
df_pca_sample = df_pca.sample(frac=0.10)
sample_mean = df_pca_sample['value_eur'].mean()
print("Sample Mean: "+str(sample_mean))
sample_std = statistics.stdev(df_pca_sample.value_eur)
print("Sample Standard Deviation: "+str(sample_std))
# Out:
# Population Mean: 1623749.959707314
# Sample Mean: 1558855.5770470663
# Sample Standard Deviation: 4037415.2808508435

# %%
from scipy.stats import pearsonr
corr, p = pearsonr(pc1, pc2)
print(p)
# Out:
# 0.084190597051422

# %%
pc1.count(), value_eur.count()
# Out:
# (31023, 31023)

# %%
import statsmodels.api as sm
X = sm.add_constant(X)
model

# %%
## Import the packages
import numpy as np
from scipy import stats

pc1 = df_pca['pc1']
pc2 = df_pca['pc2']
value_eur = df_pca['value_eur']
value_log_eur = np.log(value_eur)

N = pc1.count()

#Gaussian distributed data with mean = 2 and var = 1
a = pc1
#Gaussian distributed data with with mean = 0 and var = 1
b = value_log_eur


## Calculate the Standard Deviation
#Calculate the variance to get the standard deviation

#For unbiased max likelihood estimate we have to divide the var by N-1, and therefore the parameter ddof = 1
var_a = a.var(ddof=1)
var_b = b.var(ddof=1)

#std deviation
s = np.sqrt((var_a + var_b)/2)
s



## Calculate the t-statistics
t = (a.mean() - b.mean())/(s*np.sqrt(2/N))



## Compare with the critical t-value
#Degrees of freedom
df = 2*N - 2

#p-value after comparison with the t 
p = 1 - stats.t.cdf(t,df=df)


print("t = " + str(t))
print("p = " + str(2*p))
### You can see that after comparing the t statistic with the critical t value (computed internally) we get a good p value of 0.0005 and thus we reject the null hypothesis and thus it proves that the mean of the two distributions are different and statistically significant.


## Cross Checking with the internal scipy function
t2, p2 = stats.ttest_ind(a,b)
print("t = " + str(t2))
print("p = " + str(p2))
# Out:
# t = -551.8840214232509
# p = 2.0
# t = -551.8840214232508
# p = 0.0

# %%
## Import the packages
import numpy as np
from scipy import stats


## Define 2 random distributions
#Sample Size
N = 10
#Gaussian distributed data with mean = 2 and var = 1
a = np.random.randn(N) + 2
#Gaussian distributed data with with mean = 0 and var = 1
b = np.random.randn(N)


## Calculate the Standard Deviation
#Calculate the variance to get the standard deviation

#For unbiased max likelihood estimate we have to divide the var by N-1, and therefore the parameter ddof = 1
var_a = a.var(ddof=1)
var_b = b.var(ddof=1)

#std deviation
s = np.sqrt((var_a + var_b)/2)
s



## Calculate the t-statistics
t = (a.mean() - b.mean())/(s*np.sqrt(2/N))



## Compare with the critical t-value
#Degrees of freedom
df = 2*N - 2

#p-value after comparison with the t 
p = 1 - stats.t.cdf(t,df=df)


print("t = " + str(t))
print("p = " + str(2*p))
### You can see that after comparing the t statistic with the critical t value (computed internally) we get a good p value of 0.0005 and thus we reject the null hypothesis and thus it proves that the mean of the two distributions are different and statistically significant.


## Cross Checking with the internal scipy function
t2, p2 = stats.ttest_ind(a,b)
print("t = " + str(t2))
print("p = " + str(p2))
# Out:
# t = 5.146544097167867
# p = 6.768111728816528e-05
# t = 5.146544097167868
# p = 6.768111728802984e-05

# %%
pyplot.scatter(pc1, value_eur)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-48581d55edaf> in <module>
# ----> 1 pyplot.scatter(pc1, value_eur)
#       2 pyplot.show()
#
# NameError: name 'pyplot' is not defined

# %%
plt.rcParams['figure.figsize'] = [16, 10]
plt.hist(df_pca['pc1'], bins=15)
plt.xlabel('pc1')
plt.ylabel('number of train records')
plt.show()

# %%
plt.rcParams['figure.figsize'] = [16, 10]
plt.hist(df_pca['value_eur'], bins=300)
plt.xlabel('value')
plt.ylabel('number of train records')
plt.show()

# %%
df_pca['log_value'] = np.log(df_pca[['value_eur']])

# %%
plt.rcParams['figure.figsize'] = [16, 10]
plt.hist(df_pca['log_value'] .values, bins=100)
plt.xlabel('log(transfer values)')
plt.ylabel('number of transfer values')
plt.show()
sns.distplot(df_pca['log_value'] , bins =100)

# %%
selection = nn_df.index.to_list()
selection
# Out:
# [68017,
#  67923,
#  67916,
#  67986,
#  67856,
#  68007,
#  68241,
#  67884,
#  67902,
#  67952,
#  67949,
#  68137,
#  67923,
#  67920,
#  67826,
#  68042,
#  67839,
#  67993,
#  67909,
#  68023,
#  67921,
#  68058,
#  68165,
#  68189,
#  68403,
#  68791,
#  68601,
#  68041,
#  68142,
#  68282,
#  67953,
#  67917,
#  68788,
#  68169,
#  67885,
#  68102,
#  50664,
#  68139,
#  52003,
#  68668,
#  69117,
#  69201,
#  70250,
#  1614,
#  68166,
#  68536,
#  407,
#  68076,
#  69275,
#  68615,
#  68463,
#  68276,
#  68683,
#  68248,
#  68463,
#  35022,
#  68683,
#  68332,
#  68344,
#  68994,
#  68507,
#  68698,
#  69223,
#  68417,
#  70809,
#  67945,
#  68844,
#  69819,
#  35023,
#  70432,
#  70943,
#  53876,
#  53848,
#  55648,
#  70632,
#  70798,
#  70763,
#  71152,
#  75594,
#  73791,
#  77151,
#  76073,
#  5855,
#  39722,
#  75402,
#  55027,
#  76201,
#  72726,
#  72855,
#  79218,
#  74843,
#  59388,
#  77421,
#  73389,
#  74521,
#  76491,
#  75504,
#  76200,
#  73467,
#  74643,
#  73051,
#  62484,
#  79535,
#  75419,
#  62167,
#  11435,
#  11720,
#  77814,
#  60852,
#  79911,
#  80711,
#  81926,
#  46740,
#  63612,
#  79720,
#  80116,
#  65463,
#  15365,
#  63899,
#  80723,
#  80760,
#  81544,
#  82188,
#  81743,
#  14964,
#  15710,
#  84615,
#  83821,
#  16800]

# %%
from sklearn.model_selection import train_test_split


X = df_pca.drop(['log_value','value_eur', 'club', 'short_name'], axis=1)
y = df_pca[['log_value']]

# %%
X_selected = X.loc[selection]
y_selected = y.loc[selection]


# Split X and y into X_
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)
# Out:
# C:\Users\aaron\Anaconda3\envs\datascience\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
# C:\Users\aaron\Anaconda3\envs\datascience\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike

# %%
X_test = X_test.append(X_selected)
X_test = X_test.loc[~X_test.index.duplicated(keep='first')]
X_test = X_test.dropna()
X_test.loc[selection]
# Out:
# C:\Users\aaron\Anaconda3\envs\datascience\lib\site-packages\ipykernel_launcher.py:4: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   after removing the cwd from sys.path.
#             pc1       pc2       pc3       pc4       pc5       pc6
# 68017 -6.171037 -2.191389  2.401160 -1.984273  1.133113 -0.360958
# 67923 -7.082572 -2.466070  2.409195 -1.065906  1.148686  0.023014
# 67916 -6.772345 -2.345889  1.780103 -1.925966  1.877153 -0.394646
# 67986 -5.936113 -3.278158  2.466489  1.701635  2.090047  0.282756
# 67856 -6.263293 -3.934364  1.930044  2.385647  2.476051 -0.223277
# ...         ...       ...       ...       ...       ...       ...
# 14964  3.097826  2.405377 -0.588907 -0.086250 -0.768609 -0.583527
# 15710  1.725312  0.937247 -1.832019 -0.492002 -0.556648 -0.318654
# 84615  1.955847  0.714311 -1.969832 -0.793584 -0.510502 -0.657224
# 83821  1.827506  0.955029 -1.936989 -0.583641 -0.612428 -0.412681
# 16800  1.330244  0.391239 -2.197639 -0.657410 -0.111851 -0.518200
#
# [129 rows x 6 columns]

# %%
y_test = y_test.append(y_selected)
y_test = y_test.loc[~y_test.index.duplicated(keep='first')]
y_test = y_test.dropna()
y_test.loc[selection]
# Out:
# C:\Users\aaron\Anaconda3\envs\datascience\lib\site-packages\ipykernel_launcher.py:4: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   after removing the cwd from sys.path.
#        log_value
# 68017  17.073607
# 67923  17.370859
# 67916  17.529083
# 67986  17.216708
# 67856  16.648724
# ...          ...
# 14964  12.577636
# 15710  12.154779
# 84615  11.775290
# 83821  11.849398
# 16800  12.100712
#
# [129 rows x 1 columns]

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = regressor.predict(X_test)
print('Linear Regression R squared": %.4f' % regressor.score(X_test, y_test))
# Out:
# Linear Regression R squared": 0.7702

# %%
from sklearn.metrics import max_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_absolute_error

print('Explained Variance Score: %.4f' % explained_variance_score(y_test, pred))
print('Max Error: %.4f' % max_error(y_test, pred))
print('Mean Absolute Error: %.4f' % mean_absolute_error(y_test, pred))
print('Mean Squared Error: %.4f' % metrics.mean_squared_error(y_test, pred))  
print('Root Mean Squared Error: %.4f' %  np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# Explained Variance Score: 0.7702
# Max Error: 3.7325
# Mean Absolute Error: 0.4973
# Mean Squared Error: 0.4280
# Root Mean Squared Error: 0.6542

# %%
df_xtest = pd.DataFrame(X_test)
df_xtest.rename(columns={df_xtest.columns[0]: "pc1", df_xtest.columns[1]: "pc2", df_xtest.columns[2]: "pc3", df_xtest.columns[3]: "pc4", df_xtest.columns[4]: "pc5", df_xtest.columns[5]: "pc6"}, inplace = True)

# %%
df_ytest = pd.DataFrame(y_test)

# %%
df_merged_features = pd.merge(df_xtest, df_ytest, left_index=True, right_index=True)

# %%
df_merged_features = df_merged_features.reset_index(drop=True)

# %%
pd.options.display.float_format = '{:,.2f}'.format
df_pred = pd.DataFrame({'Predicted Log': pred.flatten()})
df_pred['Predicted'] = np.exp(df_pred) - 1
df_pred.head()
# Out:
#    Predicted Log  Predicted
# 0          13.61 817,285.51
# 1          12.54 280,653.74
# 2          12.14 186,934.62
# 3          13.04 462,286.71
# 4          13.07 475,120.73

# %%
df_merged_pred = pd.merge(df_merged_features, df_pred, left_index=True, right_index=True)
df_merged_pred
# Out:
#        pc1   pc2   pc3   pc4   pc5   pc6  log_value  Predicted Log  Predicted
# 0    -2.31  1.38  0.96  0.40 -1.27 -0.41      13.35          13.61 817,285.51
# 1     1.61  1.30 -2.82 -0.10  0.81 -0.80      12.39          12.54 280,653.74
# 2     9.26 -1.22  0.23 -0.24  0.64 -0.18      12.83          12.14 186,934.62
# 3     8.16 -0.77  0.88  0.57  1.54 -0.50      14.22          13.04 462,286.71
# 4    -0.68 -0.38 -1.02  0.98  0.07 -0.35      12.39          13.07 475,120.73
# ...    ...   ...   ...   ...   ...   ...        ...            ...        ...
# 6297  3.45  2.38 -0.82 -0.06 -0.60 -0.43      12.77          12.28 216,044.35
# 6298  3.13  2.09 -0.56 -0.27 -0.62 -0.35      12.58          12.45 255,961.23
# 6299  3.10  2.41 -0.59 -0.09 -0.77 -0.58      12.58          12.35 231,613.50
# 6300  1.83  0.96 -1.94 -0.58 -0.61 -0.41      11.85          12.10 180,656.84
# 6301  1.33  0.39 -2.20 -0.66 -0.11 -0.52      12.10          12.35 231,407.97
#
# [6302 rows x 9 columns]

# %%
df_predictions = pd.merge(df_merged_pred, df_pca, how='left', left_on=['pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'log_value'], right_on=['pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'log_value']).sort_values(by=['log_value'], ascending=False)
df_predictions
# Out:
#        pc1   pc2   pc3   pc4   pc5   pc6  log_value  Predicted Log  \
# 4607 -8.49 -3.39  2.16  0.17  2.97 -0.22      18.35          17.45
# 6203 -7.83 -1.84  2.23  2.29  2.67 -0.02      18.11          17.01
# 4611  4.49 -0.19  3.31 -0.59  5.30  0.45      18.09          17.08
# 3328 -8.96  0.17  1.13  1.44  3.43  0.30      18.02          17.43
# 3707 -5.41 -2.05  3.76 -3.43  1.07 -0.63      17.98          16.99
# ...    ...   ...   ...   ...   ...   ...        ...            ...
# 3182  1.95  1.56 -0.32  1.37 -0.84 -0.69       9.90          12.40
# 3087 10.56 -0.26  2.67  4.04 -0.67  0.24       9.90          11.66
# 1513  2.33  0.82  1.36  4.06 -2.12 -0.77       9.21          11.90
# 1127  7.84 -0.49 -0.17 -0.55  0.78 -0.63       9.21          12.40
# 2344  8.63 -1.02  0.91  0.18  0.84 -0.07       9.21          12.61
#
#          Predicted  value_eur    short_name               club
# 4607 37,977,079.10   93000000     E. Hazard            Chelsea
# 6203 24,353,360.96   73500000    C. Eriksen  Tottenham Hotspur
# 4611 26,287,199.53   72000000        De Gea  Manchester United
# 3328 37,080,425.62   67000000     L. Modrić        Real Madrid
# 3707 23,875,671.93   64500000     M. Icardi              Inter
# ...            ...        ...           ...                ...
# 3182    243,642.38      20000      T. Tsuda     Ventforet Kofu
# 3087    115,886.50      20000  D. Andersson    Helsingborgs IF
# 1513    147,828.86      10000    D. Mulcahy    Drogheda United
# 1127    242,593.63      10000    J. Kolstad      FK Bodø/Glimt
# 2344    298,425.14      10000    S. Shearer      Oxford United
#
# [6330 rows x 12 columns]

# %%
neighbors = df_pca.loc[[68017,
 67923,
 67916,
 67986,
 67856,
 68007,
 68241,
 67884,
 67902,
 67952,
 67949,
 68137,
 67923,
 67920,
 67826,
 68042,
 67839,
 67993,
 67909,
 68023,
 67921,
 68058,
 68165,
 68189,
 68403,
 68791,
 68601,
 68041,
 68142,
 68282,
 67953,
 67917,
 68788,
 68169,
 67885,
 68102,
 50664,
 68139,
 52003,
 68668,
 69117,
 69201,
 70250,
 1614,
 68166,
 68536,
 407,
 68076,
 69275,
 68615,
 68463,
 68276,
 68683,
 68248,
 68463,
 35022,
 68683,
 68332,
 68344,
 68994,
 68507,
 68698,
 69223,
 68417,
 70809,
 67945,
 68844,
 69819,
 35023,
 70432,
 70943,
 53876,
 53848,
 55648,
 70632,
 70798,
 70763,
 71152,
 75594,
 73791,
 77151,
 76073,
 5855,
 39722,
 75402,
 55027,
 76201,
 72726,
 72855,
 79218,
 74843,
 59388,
 77421,
 73389,
 74521,
 76491,
 75504,
 76200,
 73467,
 74643,
 73051,
 62484,
 79535,
 75419,
 62167,
 11435,
 11720,
 77814,
 60852,
 79911,
 80711,
 81926,
 46740,
 63612,
 79720,
 80116,
 65463,
 15365,
 63899,
 80723,
 80760,
 81544,
 82188,
 81743,
 14964,
 15710,
 84615,
 83821,
 16800]]
# Out:
# C:\Users\aaron\Anaconda3\envs\datascience\lib\site-packages\ipykernel_launcher.py:129: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike

# %%
predictions = pd.merge(df_predictions, neighbors, how='right', left_on=['pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'value_eur', 'short_name', 'club', 'log_value'], right_on=['pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'value_eur', 'short_name', 'club', 'log_value']).sort_values(by=['log_value'], ascending=False)

# %%
scouting_report_pred = pd.merge(predictions, nn_df, how='right', left_on=['pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'value_eur', 'short_name', 'club'], right_on=['pc1', 'pc2', 'pc3', 'pc4', 'pc5', 'pc6', 'value_eur', 'short_name', 'club'])
scouting_report_pred = scouting_report_pred.dropna()
scouting_report_pred.sort_values(by=['transfer'])
# Out:
#       pc1   pc2   pc3   pc4   pc5   pc6  log_value  Predicted Log  \
# 66  -2.67 -2.61  1.42  0.72  1.00 -0.47      15.52          14.89
# 80  -2.69 -2.50  0.60  0.01  1.28 -0.45      14.46          14.81
# 74  -2.81 -2.52  0.68  0.08  0.95 -0.51      14.91          14.67
# 71  -2.81 -2.56  0.75  0.05  1.02 -0.48      15.15          14.74
# 7   -7.08 -2.47  2.41 -1.07  1.15  0.02      17.37          16.46
# ..    ...   ...   ...   ...   ...   ...        ...            ...
# 0   -1.88  5.34  1.71 -1.21  1.53 -0.57      17.65          15.88
# 122  3.13  2.09 -0.56 -0.27 -0.62 -0.35      12.58          12.45
# 123  3.10  2.41 -0.59 -0.09 -0.77 -0.58      12.58          12.35
# 119  3.45  2.38 -0.82 -0.06 -0.60 -0.43      12.77          12.28
# 121  3.16  2.18 -0.35 -0.02 -0.70 -0.54      12.69          12.46
#
#         Predicted     value_eur         short_name                club  \
# 66   2,937,542.59  5,500,000.00       A. Miranchuk    Lokomotiv Moscow
# 80   2,704,041.23  1,900,000.00       F. Lecarnado        CD Palestino
# 74   2,344,928.43  3,000,000.00        L. Cinterio    Deportes Iquique
# 71   2,515,089.87  3,800,000.00  Gustavo Lobateiro       Internacional
# 7   14,143,666.62 35,000,000.00           M. Depay  Olympique Lyonnais
# ..            ...           ...                ...                 ...
# 0    7,861,611.85 46,500,000.00        M. Škriniar               Inter
# 122    255,961.23    290,000.00          T. Rieder     SV Darmstadt 98
# 123    231,613.50    290,000.00        J. Finnerty         Bohemian FC
# 119    216,044.35    350,000.00         G. Cardozo      Extremadura UD
# 121    257,532.84    325,000.00          J. Yarney           Morecambe
#
#          transfer
# 66       A. Iwobi
# 80       A. Iwobi
# 74       A. Iwobi
# 71       A. Iwobi
# 7    A. Lacazette
# ..            ...
# 0        Sokratis
# 122     Z. Medley
# 123     Z. Medley
# 119     Z. Medley
# 121     Z. Medley
#
# [133 rows x 13 columns]

# %%
scouting_actual_pred = scouting_report_pred[['Predicted', 'value_eur', 'short_name', 'transfer']]
scouting_actual_pred = scouting_actual_pred.rename(columns={"value_eur": "Actual", 'short_name': 'Name', 'transfer':'Transfer'})
scouting_actual_pred = scouting_actual_pred.set_index('Name')
scouting_actual_pred = scouting_actual_pred.drop_duplicates()
scouting_actual_pred.sort_values(by=['Transfer'])
# Out:
#                       Predicted        Actual      Transfer
# Name
# A. Miranchuk       2,937,542.59  5,500,000.00      A. Iwobi
# Gustavo Lobateiro  2,515,089.87  3,800,000.00      A. Iwobi
# F. Lecarnado       2,704,041.23  1,900,000.00      A. Iwobi
# L. Cinterio        2,344,928.43  3,000,000.00      A. Iwobi
# K. Gameiro        16,049,719.37 16,000,000.00  A. Lacazette
# ...                         ...           ...           ...
# M. Škriniar        7,861,611.85 46,500,000.00      Sokratis
# G. Cardozo           216,044.35    350,000.00     Z. Medley
# J. Yarney            257,532.84    325,000.00     Z. Medley
# T. Rieder            255,961.23    290,000.00     Z. Medley
# J. Finnerty          231,613.50    290,000.00     Z. Medley
#
# [127 rows x 3 columns]

# %%
lm = sns.lmplot(x="Predicted", y="value_eur", data=df_predictions, line_kws={'color': 'red'}, fit_reg=True)

# Get hold of the `Axes` objects
axes = lm.ax

plt.title('Predicted vs Actual FIFA Market Values')

# Set x-axis label
plt.xlabel('Predicted Market Value')
# Set y-axis label
plt.ylabel('Actual Market Value')

# Show the plot
plt.show()

# %%
lm = sns.lmplot(x="Predicted", y="value_eur", data=scouting_report_pred)

# Get hold of the `Axes` objects
axes = lm.ax

plt.title('Predicted vs Actual FIFA Market Values')

# Set x-axis label
plt.xlabel('Predicted Market Value')
# Set y-axis label
plt.ylabel('Actual Market Value')

# Show the plot
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from yellowbrick.datasets import load_concrete
from yellowbrick.regressor import ResidualsPlot

# Instantiate the linear model and visualizer
model = Ridge()

visualizer = ResidualsPlot(model, hist=False)
visualizer.fit(X_train, y_train)
visualizer.score(X_test, y_test)
visualizer.show()             # Finalize and render the figure

# %%
scouting_actual_pred.plot(kind='bar',figsize=(40,20))
plt.grid(which='major', linestyle='-', linewidth='0.1', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.1', color='black')
plt.ylabel('Transfer Value', fontsize=18)
plt.xlabel('Target Players', fontsize=18)
plt.title('Predicted vs Actual Transfer Target Values for Replacement Options for Arsenal Players', fontsize=38)
plt.show()
