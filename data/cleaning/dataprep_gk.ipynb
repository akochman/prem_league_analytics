# %%
import numpy as np
import pandas as pd
import seaborn as sns
import fuzzywuzzy
import matplotlib.pyplot as plt
from scipy import stats
import janitor as jn
import pandas_profiling
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gk_stats.csv')

# %%
Xbad = df
jn.clean_names(Xbad)
Xbad.head()
# Out:
#    Unnamed: 0 fifa_name  overall             club  value_eur  wage_eur  \
# 0           0   Alisson       89        Liverpool   58000000    155000
# 1           1   Alisson       85        Liverpool   36500000    115000
# 2           2   Alisson       89        Liverpool   58000000    155000
# 3           3   Alisson       85        Liverpool   36500000    115000
# 4           4   Ederson       88  Manchester City   54500000    185000
#
#   player_positions   year  potential player_positions.1 preferred_foot  \
# 0               GK  19/20         91                 GK          Right
# 1               GK  18/19         90                 GK          Right
# 2               GK  19/20         91                 GK          Right
# 3               GK  18/19         90                 GK          Right
# 4               GK  19/20         91                 GK           Left
#
#    international_reputation  weak_foot  skill_moves team_position  \
# ...

# %%
def clean_col(name):
    return (
        name.strip().lower().replace(" ", "_")
    )
Xbad.rename(columns=clean_col)
Xbad.head()
# Out:
#    Unnamed: 0 fifa_name  overall             club  value_eur  wage_eur  \
# 0           0   Alisson       89        Liverpool   58000000    155000
# 1           1   Alisson       85        Liverpool   36500000    115000
# 2           2   Alisson       89        Liverpool   58000000    155000
# 3           3   Alisson       85        Liverpool   36500000    115000
# 4           4   Ederson       88  Manchester City   54500000    185000
#
#   player_positions   year  potential player_positions.1 preferred_foot  \
# 0               GK  19/20         91                 GK          Right
# 1               GK  18/19         90                 GK          Right
# 2               GK  19/20         91                 GK          Right
# 3               GK  18/19         90                 GK          Right
# 4               GK  19/20         91                 GK           Left
#
#    international_reputation  weak_foot  skill_moves team_position  \
# ...

# %%
Xbad = Xbad.fillna(0)
Xbad.head()
# Out:
#    Unnamed: 0 fifa_name  overall             club  value_eur  wage_eur  \
# 0           0   Alisson       89        Liverpool   58000000    155000
# 1           1   Alisson       85        Liverpool   36500000    115000
# 2           2   Alisson       89        Liverpool   58000000    155000
# 3           3   Alisson       85        Liverpool   36500000    115000
# 4           4   Ederson       88  Manchester City   54500000    185000
#
#   player_positions   year  potential player_positions.1 preferred_foot  \
# 0               GK  19/20         91                 GK          Right
# 1               GK  18/19         90                 GK          Right
# 2               GK  19/20         91                 GK          Right
# 3               GK  18/19         90                 GK          Right
# 4               GK  19/20         91                 GK           Left
#
#    international_reputation  weak_foot  skill_moves team_position  \
# ...

# %%
Xbad.isna().any().any()
# Out:
# False

# %%
Xbad = Xbad.drop(columns=['Unnamed: 0'])
Xbad.head()
# Out:
#   fifa_name  overall             club  value_eur  wage_eur player_positions  \
# 0   Alisson       89        Liverpool   58000000    155000               GK
# 1   Alisson       85        Liverpool   36500000    115000               GK
# 2   Alisson       89        Liverpool   58000000    155000               GK
# 3   Alisson       85        Liverpool   36500000    115000               GK
# 4   Ederson       88  Manchester City   54500000    185000               GK
#
#     year  potential player_positions.1 preferred_foot  \
# 0  19/20         91                 GK          Right
# 1  18/19         90                 GK          Right
# 2  19/20         91                 GK          Right
# 3  18/19         90                 GK          Right
# 4  19/20         91                 GK           Left
#
#    international_reputation  weak_foot  skill_moves team_position  \
# 0                         3          3            1            GK
# ...

# %%
Xbad['attacking_crossing'] = Xbad['attacking_crossing'].str[:2]
Xbad['attacking_finishing'] = Xbad['attacking_finishing'].str[:2]
Xbad['attacking_heading_accuracy'] = Xbad['attacking_heading_accuracy'].str[:2]
Xbad['attacking_short_passing'] = Xbad['attacking_short_passing'].str[:2]
Xbad['attacking_volleys'] = Xbad['attacking_volleys'].str[:2]
Xbad['skill_dribbling'] = Xbad['skill_dribbling'].str[:2]
Xbad['skill_curve'] = Xbad['skill_curve'].str[:2]
Xbad['skill_fk_accuracy'] = Xbad['skill_fk_accuracy'].str[:2]
Xbad['skill_long_passing'] = Xbad['skill_long_passing'].str[:2]
Xbad['skill_ball_control'] = Xbad['skill_ball_control'].str[:2]
Xbad['movement_acceleration'] = Xbad['movement_acceleration'].str[:2]
Xbad['movement_sprint_speed'] = Xbad['movement_sprint_speed'].str[:2]
Xbad['movement_agility'] = Xbad['movement_agility'].str[:2]
Xbad['movement_reactions'] = Xbad['movement_reactions'].str[:2]
Xbad['movement_balance'] = Xbad['movement_balance'].str[:2]
Xbad['power_shot_power'] = Xbad['power_shot_power'].str[:2]
Xbad['power_jumping'] = Xbad['power_jumping'].str[:2]
Xbad['power_stamina'] = Xbad['power_stamina'].str[:2]
Xbad['power_strength'] = Xbad['power_strength'].str[:2]
Xbad['power_long_shots'] = Xbad['power_long_shots'].str[:2]
Xbad['mentality_aggression'] = Xbad['mentality_aggression'].str[:2]
Xbad['mentality_interceptions'] = Xbad['mentality_interceptions'].str[:2]
Xbad['mentality_positioning'] = Xbad['mentality_positioning'].str[:2]
Xbad['mentality_vision'] = Xbad['mentality_vision'].str[:2]
Xbad['mentality_penalties'] = Xbad['mentality_penalties'].str[:2]
Xbad['mentality_composure'] = Xbad['mentality_composure'].str[:2]
Xbad['defending_marking'] = Xbad['defending_marking'].str[:2]
Xbad['defending_standing_tackle'] = Xbad['defending_standing_tackle'].str[:2]
Xbad['defending_sliding_tackle'] = Xbad['defending_sliding_tackle'].str[:2]
Xbad['goalkeeping_diving'] = Xbad['goalkeeping_diving'].str[:2]
Xbad['goalkeeping_handling'] = Xbad['goalkeeping_handling'].str[:2]
Xbad['goalkeeping_kicking'] = Xbad['goalkeeping_kicking'].str[:2]
Xbad['goalkeeping_positioning'] = Xbad['goalkeeping_positioning'].str[:2]
Xbad['goalkeeping_reflexes'] = Xbad['goalkeeping_reflexes'].str[:2]

# %%
Xbad = Xbad.drop_duplicates(subset=['fifa_name', 'year'])
Xbad.head()
# Out:
#   fifa_name  overall             club  value_eur  wage_eur player_positions  \
# 0   Alisson       89        Liverpool   58000000    155000               GK
# 1   Alisson       85        Liverpool   36500000    115000               GK
# 4   Ederson       88  Manchester City   54500000    185000               GK
# 5   Ederson       83  Manchester City   26000000     87000               GK
# 6   Ederson       86  Manchester City   41500000    125000               GK
#
#     year  potential player_positions.1 preferred_foot  \
# 0  19/20         91                 GK          Right
# 1  18/19         90                 GK          Right
# 4  19/20         91                 GK           Left
# 5  17/18         89                 GK           Left
# 6  18/19         90                 GK           Left
#
#    international_reputation  weak_foot  skill_moves team_position  \
# 0                         3          3            1            GK
# ...

# %%
Xbad.to_csv('gk_stats_clean.csv')
