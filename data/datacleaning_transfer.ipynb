# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
#transfermarkt data cleaning
path = r'C:\\Users\\aaron\\prem_league_analytics\\data\\'
df_tm_transfer = pd.read_csv(path+'transfer.csv')

# %%
df_tm_transfer.head()
# Out:
#               name  age  height                position   foot  \
# 0          Ederson   26   188.0              Goalkeeper   left
# 1    Claudio Bravo   36   184.0              Goalkeeper  right
# 2     Scott Carson   34   188.0              Goalkeeper  right
# 3  Aymeric Laporte   25   191.0  Defender - Centre-Back   left
# 4      John Stones   25   188.0  Defender - Centre-Back  right
#
#       current club   09/10 date     09/10 left 09/10 joined 09/10 mv  ...  \
# 0  Manchester City  Jan 1, 2010  São Paulo U17  Benfica U17        0  ...
# 1  Manchester City          NaN            NaN          NaN      NaN  ...
# 2  Manchester City          NaN            NaN          NaN      NaN  ...
# 3  Manchester City          NaN            NaN          NaN      NaN  ...
# 4  Manchester City          NaN            NaN          NaN      NaN  ...
#
#   00/01 date 00/01 left 00/01 joined 00/01 mv 00/01 fee 97/98 date 97/98 left  \
# 0        NaN        NaN          NaN      NaN       NaN        NaN        NaN
# 1        NaN        NaN          NaN      NaN       NaN        NaN        NaN
# 2        NaN        NaN          NaN      NaN       NaN        NaN        NaN
# 3        NaN        NaN          NaN      NaN       NaN        NaN        NaN
# 4        NaN        NaN          NaN      NaN       NaN        NaN        NaN
#
#   97/98 joined 97/98 mv 97/98 fee
# 0          NaN      NaN       NaN
# 1          NaN      NaN       NaN
# 2          NaN      NaN       NaN
# 3          NaN      NaN       NaN
# 4          NaN      NaN       NaN
#
# [5 rows x 122 columns]

# %%
df_trans16 = df_tm_transfer[['name','age', 'height', 'position', 'current club', '15/16 date', '15/16 left', '15/16 joined', '15/16 mv']]
df_trans17 = df_tm_transfer[['name','age', 'height', 'position', 'current club', '16/17 date', '16/17 left', '16/17 joined', '16/17 mv']]
df_trans18 = df_tm_transfer[['name','age', 'height', 'position', 'current club', '17/18 date', '17/18 left', '17/18 joined', '17/18 mv']]
df_trans19 = df_tm_transfer[['name','age', 'height', 'position', 'current club', '18/19 date', '18/19 left', '18/19 joined', '18/19 mv']]
df_trans20 = df_tm_transfer[['name','age', 'height', 'position', 'current club', '19/20 date', '19/20 left', '19/20 joined', '19/20 mv']]

# %%
path = r'C:\Users\aaron\prem_league_analytics\data\transfermarkt\transfer_data\ '

df_trans16.to_csv(path+'trans16.csv')
df_trans17.to_csv(path+'trans17.csv')
df_trans18.to_csv(path+'trans18.csv')
df_trans19.to_csv(path+'trans19.csv')
df_trans20.to_csv(path+'trans20.csv')

# %%
df_trans16 = pd.read_csv(path+'trans16.csv')
df_trans16['year'] = '15/16'
df_trans17 = pd.read_csv(path+'trans17.csv')
df_trans17['year'] = '16/17'
df_trans18 = pd.read_csv(path+'trans18.csv')
df_trans18['year'] = '17/18'
df_trans19 = pd.read_csv(path+'trans19.csv')
df_trans19['year'] = '18/19'
df_trans20 = pd.read_csv(path+'trans20.csv')
df_trans20['year'] = '19/20'

# %%
df_trans16.rename(columns={'15/16 date':'date','15/16 left': 'left', '15/16 joined' : 'joined', '15/16 mv': 'mv'} , inplace=True)
df_trans17.rename(columns={'16/17 date':'date','16/17 left': 'left', '16/17 joined' : 'joined', '16/17 mv': 'mv'} , inplace=True)
df_trans18.rename(columns={'17/18 date':'date','17/18 left': 'left', '17/18 joined' : 'joined', '17/18 mv': 'mv'} , inplace=True)
df_trans19.rename(columns={'18/19 date':'date','18/19 left': 'left', '18/19 joined' : 'joined', '18/19 mv': 'mv'} , inplace=True)
df_trans20.rename(columns={'19/20 date':'date','19/20 left': 'left', '19/20 joined' : 'joined', '19/20 mv': 'mv'} , inplace=True)

# %%
df_trans = pd.concat([df_trans16, df_trans17, df_trans18, df_trans19, df_trans20], sort=False)
df_trans
# Out:
#      Unnamed: 0              name  age  height                  position  \
# 0             0           Ederson   26   188.0                Goalkeeper
# 1             1     Claudio Bravo   36   184.0                Goalkeeper
# 2             2      Scott Carson   34   188.0                Goalkeeper
# 3             3   Aymeric Laporte   25   191.0    Defender - Centre-Back
# 4             4       John Stones   25   188.0    Defender - Centre-Back
# ..          ...               ...  ...     ...                       ...
# 502         502   Oliver McBurnie   23   188.0  Forward - Centre-Forward
# 503         503       Lys Mousset   23   184.0  Forward - Centre-Forward
# 504         504       Billy Sharp   33   175.0  Forward - Centre-Forward
# 505         505  David McGoldrick   31   184.0  Forward - Centre-Forward
# 506         506       Leon Clarke   34   188.0  Forward - Centre-Forward
#
#          current club          date         left          joined           mv  \
# 0     Manchester City   Jul 1, 2015   Rio Ave FC         Benfica  1,20 mil. €
# 1     Manchester City           NaN          NaN             NaN          NaN
# 2     Manchester City   Jul 1, 2015        Wigan           Derby  2,00 mil. €
# 3     Manchester City           NaN          NaN             NaN          NaN
# 4     Manchester City           NaN          NaN             NaN          NaN
# ..                ...           ...          ...             ...          ...
# 502  Sheffield United   Aug 2, 2019      Swansea  Sheffield Utd.  8,00 mil. €
# 503  Sheffield United  Jul 21, 2019  Bournemouth  Sheffield Utd.  3,50 mil. €
# 504  Sheffield United           NaN          NaN             NaN          NaN
# 505  Sheffield United           NaN          NaN             NaN          NaN
# 506  Sheffield United           NaN          NaN             NaN          NaN
#
#       year
# 0    15/16
# 1    15/16
# 2    15/16
# 3    15/16
# 4    15/16
# ..     ...
# 502  19/20
# 503  19/20
# 504  19/20
# 505  19/20
# 506  19/20
#
# [2535 rows x 11 columns]

# %%
df_trans['firstinitial'] = df_trans['name'].astype(str).str[0]
df_trans['lastname'] = df_trans['name'].str.split(' ').str[1]
df_trans['short_name']=df_trans['firstinitial'].astype(str)+'. '+df_trans['lastname']
df_trans = df_trans.replace('Arsenal FC U23', 'Arsenal FC')
df_trans
# Out:
#      Unnamed: 0              name  age  height                  position  \
# 0             0           Ederson   26   188.0                Goalkeeper
# 1             1     Claudio Bravo   36   184.0                Goalkeeper
# 2             2      Scott Carson   34   188.0                Goalkeeper
# 3             3   Aymeric Laporte   25   191.0    Defender - Centre-Back
# 4             4       John Stones   25   188.0    Defender - Centre-Back
# ..          ...               ...  ...     ...                       ...
# 502         502   Oliver McBurnie   23   188.0  Forward - Centre-Forward
# 503         503       Lys Mousset   23   184.0  Forward - Centre-Forward
# 504         504       Billy Sharp   33   175.0  Forward - Centre-Forward
# 505         505  David McGoldrick   31   184.0  Forward - Centre-Forward
# 506         506       Leon Clarke   34   188.0  Forward - Centre-Forward
#
#          current club          date         left          joined           mv  \
# 0     Manchester City   Jul 1, 2015   Rio Ave FC         Benfica  1,20 mil. €
# 1     Manchester City           NaN          NaN             NaN          NaN
# 2     Manchester City   Jul 1, 2015        Wigan           Derby  2,00 mil. €
# 3     Manchester City           NaN          NaN             NaN          NaN
# 4     Manchester City           NaN          NaN             NaN          NaN
# ..                ...           ...          ...             ...          ...
# 502  Sheffield United   Aug 2, 2019      Swansea  Sheffield Utd.  8,00 mil. €
# 503  Sheffield United  Jul 21, 2019  Bournemouth  Sheffield Utd.  3,50 mil. €
# 504  Sheffield United           NaN          NaN             NaN          NaN
# 505  Sheffield United           NaN          NaN             NaN          NaN
# 506  Sheffield United           NaN          NaN             NaN          NaN
#
#       year firstinitial    lastname     short_name
# 0    15/16            E         NaN            NaN
# 1    15/16            C       Bravo       C. Bravo
# 2    15/16            S      Carson      S. Carson
# 3    15/16            A     Laporte     A. Laporte
# 4    15/16            J      Stones      J. Stones
# ..     ...          ...         ...            ...
# 502  19/20            O    McBurnie    O. McBurnie
# 503  19/20            L     Mousset     L. Mousset
# 504  19/20            B       Sharp       B. Sharp
# 505  19/20            D  McGoldrick  D. McGoldrick
# 506  19/20            L      Clarke      L. Clarke
#
# [2535 rows x 14 columns]

# %%
df_trans = df_trans.drop(columns=['Unnamed: 0','firstinitial', 'lastname'])
#df_trans = df_trans.dropna()
df_trans
# Out:
#                  name  age  height                  position  \
# 0             Ederson   26   188.0                Goalkeeper
# 1       Claudio Bravo   36   184.0                Goalkeeper
# 2        Scott Carson   34   188.0                Goalkeeper
# 3     Aymeric Laporte   25   191.0    Defender - Centre-Back
# 4         John Stones   25   188.0    Defender - Centre-Back
# ..                ...  ...     ...                       ...
# 502   Oliver McBurnie   23   188.0  Forward - Centre-Forward
# 503       Lys Mousset   23   184.0  Forward - Centre-Forward
# 504       Billy Sharp   33   175.0  Forward - Centre-Forward
# 505  David McGoldrick   31   184.0  Forward - Centre-Forward
# 506       Leon Clarke   34   188.0  Forward - Centre-Forward
#
#          current club          date         left          joined           mv  \
# 0     Manchester City   Jul 1, 2015   Rio Ave FC         Benfica  1,20 mil. €
# 1     Manchester City           NaN          NaN             NaN          NaN
# 2     Manchester City   Jul 1, 2015        Wigan           Derby  2,00 mil. €
# 3     Manchester City           NaN          NaN             NaN          NaN
# 4     Manchester City           NaN          NaN             NaN          NaN
# ..                ...           ...          ...             ...          ...
# 502  Sheffield United   Aug 2, 2019      Swansea  Sheffield Utd.  8,00 mil. €
# 503  Sheffield United  Jul 21, 2019  Bournemouth  Sheffield Utd.  3,50 mil. €
# 504  Sheffield United           NaN          NaN             NaN          NaN
# 505  Sheffield United           NaN          NaN             NaN          NaN
# 506  Sheffield United           NaN          NaN             NaN          NaN
#
#       year     short_name
# 0    15/16            NaN
# 1    15/16       C. Bravo
# 2    15/16      S. Carson
# 3    15/16     A. Laporte
# 4    15/16      J. Stones
# ..     ...            ...
# 502  19/20    O. McBurnie
# 503  19/20     L. Mousset
# 504  19/20       B. Sharp
# 505  19/20  D. McGoldrick
# 506  19/20      L. Clarke
#
# [2535 rows x 11 columns]

# %%
df_trans['mv'].replace(',00','',regex=True,inplace=True)
df_trans['mv'].replace(',20','',regex=True,inplace=True)
df_trans['mv'].replace(',25','',regex=True,inplace=True)
df_trans['mv'].replace(',50','',regex=True,inplace=True)
df_trans['mv'].replace(' mil. €','000000',regex=True,inplace=True)
df_trans['mv'].replace(' thousand €','000',regex=True,inplace=True)
df_trans['mv'].replace(' K €','000',regex=True,inplace=True)
df_trans['mv'].replace(' 550 K â‚¬','000',regex=True,inplace=True)
df_trans['mv'].replace('550 K â‚¬','000',regex=True,inplace=True)
df_trans[['mv']] = df_trans[['mv']].fillna(value=0)

# %%
df_trans['mv'] = df_trans['mv'].astype('str')

# %%
df_trans = df_trans[df_trans['mv'].map(len) < 10]
df_trans = df_trans[df_trans['mv'].map(len) > 1]
df_trans
# Out:
#                  name  age  height                         position  \
# 0             Ederson   26   188.0                       Goalkeeper
# 2        Scott Carson   34   188.0                       Goalkeeper
# 5    Nicolás Otamendi   31   183.0           Defender - Centre-Back
# 10       João Cancelo   25   182.0            Defender - Right-Back
# 16    Kevin De Bruyne   28   181.0  Midfielder - Attacking Midfield
# ..                ...  ...     ...                              ...
# 497        Ben Osborn   25   176.0       Midfielder - Left Midfield
# 499    Ravel Morrison   26   175.0  Midfielder - Attacking Midfield
# 500   Callum Robinson   24   178.0            Forward - Left Winger
# 502   Oliver McBurnie   23   188.0         Forward - Centre-Forward
# 503       Lys Mousset   23   184.0         Forward - Centre-Forward
#
#          current club          date           left          joined        mv  \
# 0     Manchester City   Jul 1, 2015     Rio Ave FC         Benfica   1000000
# 2     Manchester City   Jul 1, 2015          Wigan           Derby   2000000
# 5     Manchester City  Aug 20, 2015       Valencia        Man City  25000000
# 10    Manchester City   Jul 1, 2015        Benfica        Valencia   5000000
# 16    Manchester City  Aug 30, 2015  VfL Wolfsburg        Man City  45000000
# ..                ...           ...            ...             ...       ...
# 497  Sheffield United  Jul 26, 2019   Nottm Forest  Sheffield Utd.   3000000
# 499  Sheffield United  Jul 16, 2019      Östersund  Sheffield Utd.    300000
# 500  Sheffield United  Jul 12, 2019     Preston NE  Sheffield Utd.   4000000
# 502  Sheffield United   Aug 2, 2019        Swansea  Sheffield Utd.   8000000
# 503  Sheffield United  Jul 21, 2019    Bournemouth  Sheffield Utd.   3000000
#
#       year   short_name
# 0    15/16          NaN
# 2    15/16    S. Carson
# 5    15/16  N. Otamendi
# 10   15/16   J. Cancelo
# 16   15/16        K. De
# ..     ...          ...
# 497  19/20    B. Osborn
# 499  19/20  R. Morrison
# 500  19/20  C. Robinson
# 502  19/20  O. McBurnie
# 503  19/20   L. Mousset
#
# [525 rows x 11 columns]

# %%
df_trans['mv'] = pd.to_numeric(df_trans['mv'])
df_trans
# Out:
#                  name  age  height                         position  \
# 0             Ederson   26   188.0                       Goalkeeper
# 2        Scott Carson   34   188.0                       Goalkeeper
# 5    Nicolás Otamendi   31   183.0           Defender - Centre-Back
# 10       João Cancelo   25   182.0            Defender - Right-Back
# 16    Kevin De Bruyne   28   181.0  Midfielder - Attacking Midfield
# ..                ...  ...     ...                              ...
# 497        Ben Osborn   25   176.0       Midfielder - Left Midfield
# 499    Ravel Morrison   26   175.0  Midfielder - Attacking Midfield
# 500   Callum Robinson   24   178.0            Forward - Left Winger
# 502   Oliver McBurnie   23   188.0         Forward - Centre-Forward
# 503       Lys Mousset   23   184.0         Forward - Centre-Forward
#
#          current club          date           left          joined  \
# 0     Manchester City   Jul 1, 2015     Rio Ave FC         Benfica
# 2     Manchester City   Jul 1, 2015          Wigan           Derby
# 5     Manchester City  Aug 20, 2015       Valencia        Man City
# 10    Manchester City   Jul 1, 2015        Benfica        Valencia
# 16    Manchester City  Aug 30, 2015  VfL Wolfsburg        Man City
# ..                ...           ...            ...             ...
# 497  Sheffield United  Jul 26, 2019   Nottm Forest  Sheffield Utd.
# 499  Sheffield United  Jul 16, 2019      Östersund  Sheffield Utd.
# 500  Sheffield United  Jul 12, 2019     Preston NE  Sheffield Utd.
# 502  Sheffield United   Aug 2, 2019        Swansea  Sheffield Utd.
# 503  Sheffield United  Jul 21, 2019    Bournemouth  Sheffield Utd.
#
#              mv   year   short_name
# 0     1000000.0  15/16          NaN
# 2     2000000.0  15/16    S. Carson
# 5    25000000.0  15/16  N. Otamendi
# 10    5000000.0  15/16   J. Cancelo
# 16   45000000.0  15/16        K. De
# ..          ...    ...          ...
# 497   3000000.0  19/20    B. Osborn
# 499    300000.0  19/20  R. Morrison
# 500   4000000.0  19/20  C. Robinson
# 502   8000000.0  19/20  O. McBurnie
# 503   3000000.0  19/20   L. Mousset
#
# [525 rows x 11 columns]

# %%
path = r'C:\Users\aaron\prem_league_analytics\data\ml_analysis\ '
df_trans.to_csv(path+'trans.csv')

# %%
order_mv = df_trans.groupby(by=['current club'])['mv'].median().sort_values(ascending=False).index

# %%
#Historical trends from 
ax=sns.catplot(x="current club", y="mv", kind="box", order=order_mv, data=df_trans)
ax.fig.set_size_inches(25,20)
ax.set_xticklabels(rotation=90)
plt.title('MV by Club from 2015-2019')
plt.show()
