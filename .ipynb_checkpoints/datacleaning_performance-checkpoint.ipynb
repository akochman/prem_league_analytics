# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
#transfermarkt data cleaning
path = r'C:\\Users\\aaron\\prem_league_analytics\\data\\'
df_tm_performance = pd.read_csv(path+'Performance.csv')

# %%
df_tm_performance.head()
# Out:
#                   name  age  height position   foot     current club  \
# 0      Aymeric Laporte   25   191.0        W   left  Manchester City
# 1          John Stones   25   188.0        W  right  Manchester City
# 2     Nicolás Otamendi   31   183.0        W  right  Manchester City
# 3       Benjamin Mendy   25   185.0        W   left  Manchester City
# 4  Oleksandr Zinchenko   22   175.0        W   left  Manchester City
#
#    14/15 games  14/15 goals  14/15 assists  14/15 minutes  ...  17/18 minutes  \
# 0         49.0          0.0            1.0         4310.0  ...         3867.0
# 1         28.0          1.0            0.0         2426.0  ...         2234.0
# 2         38.0          6.0            0.0         3362.0  ...         4048.0
# 3         35.0          0.0            6.0         3059.0  ...          496.0
# 4          7.0          0.0            0.0          234.0  ...         1104.0
#
#    18/19 games  18/19 goals  18/19 assists  18/19 minutes  19/20 games  \
# 0         51.0          5.0            3.0         4352.0          4.0
# 1         39.0          0.0            1.0         2820.0          2.0
# 2         33.0          1.0            1.0         2478.0          4.0
# 3         15.0          0.0            5.0         1270.0          NaN
# 4         29.0          1.0            5.0         2339.0          5.0
#
#    19/20 goals  19/20 assists  19/20 minutes  current league
# 0          0.0            0.0          307.0  Premier League
# 1          0.0            0.0          180.0  Premier League
# 2          0.0            0.0          360.0  Premier League
# 3          NaN            NaN            NaN  Premier League
# 4          0.0            0.0          450.0  Premier League
#
# [5 rows x 31 columns]

# %%
df_perf16 = df_tm_performance[['name','age', 'height', 'position', 'current club', '15/16 games', '15/16 goals', '15/16 assists', '15/16 minutes']]
df_perf17 = df_tm_performance[['name','age', 'height', 'position', 'current club', '16/17 games', '16/17 goals', '16/17 assists', '16/17 minutes']]
df_perf18 = df_tm_performance[['name','age', 'height', 'position', 'current club', '17/18 games', '17/18 goals', '17/18 assists', '17/18 minutes']]
df_perf19 = df_tm_performance[['name','age', 'height', 'position', 'current club', '18/19 games', '18/19 goals', '18/19 assists', '18/19 minutes']]
df_perf20 = df_tm_performance[['name','age', 'height', 'position', 'current club', '19/20 games', '19/20 goals', '19/20 assists', '19/20 minutes']]

# %%
path = r'C:\Users\aaron\prem_league_analytics\data\transfermarkt\performance_data\ '

df_perf16.to_csv(path+'perf16.csv')
df_perf17.to_csv(path+'perf17.csv')
df_perf18.to_csv(path+'perf18.csv')
df_perf19.to_csv(path+'perf19.csv')
df_perf20.to_csv(path+'perf20.csv')

# %%
df_perf16 = pd.read_csv(path+'perf16.csv')
df_perf16['year'] = '15/16'
df_perf17 = pd.read_csv(path+'perf17.csv')
df_perf17['year'] = '16/17'
df_perf18 = pd.read_csv(path+'perf18.csv')
df_perf18['year'] = '17/18'
df_perf19 = pd.read_csv(path+'perf19.csv')
df_perf19['year'] = '18/19'
df_perf20 = pd.read_csv(path+'perf20.csv')
df_perf20['year'] = '19/20'

# %%
df_perf16.rename(columns={'15/16 games':'games','15/16 goals': 'goals', '15/16 assists' : 'assists', '15/16 minutes': 'minutes'} , inplace=True)
df_perf17.rename(columns={'16/17 games':'games','16/17 goals': 'goals', '16/17 assists' : 'assists', '16/17 minutes': 'minutes'} , inplace=True)
df_perf18.rename(columns={'17/18 games':'games','17/18 goals': 'goals', '17/18 assists' : 'assists', '17/18 minutes': 'minutes'} , inplace=True)
df_perf19.rename(columns={'18/19 games':'games','18/19 goals': 'goals', '18/19 assists' : 'assists', '18/19 minutes': 'minutes'} , inplace=True)
df_perf20.rename(columns={'19/20 games':'games','19/20 goals': 'goals', '19/20 assists' : 'assists', '19/20 minutes': 'minutes'} , inplace=True)

# %%
df_perf = pd.concat([df_perf16, df_perf17, df_perf18, df_perf19, df_perf20], sort=False)
df_perf
# Out:
#      Unnamed: 0                 name  age  height position      current club  \
# 0             0      Aymeric Laporte   25   191.0        W   Manchester City
# 1             1          John Stones   25   188.0        W   Manchester City
# 2             2     Nicolás Otamendi   31   183.0        W   Manchester City
# 3             3       Benjamin Mendy   25   185.0        W   Manchester City
# 4             4  Oleksandr Zinchenko   22   175.0        W   Manchester City
# ..          ...                  ...  ...     ...      ...               ...
# 436         436      Oliver McBurnie   23   188.0       CF  Sheffield United
# 437         437          Lys Mousset   23   184.0       CF  Sheffield United
# 438         438          Billy Sharp   33   175.0       CF  Sheffield United
# 439         439     David McGoldrick   31   184.0       CF  Sheffield United
# 440         440          Leon Clarke   34   188.0       CF  Sheffield United
#
#      games  goals  assists  minutes   year
# 0     45.0    5.0      2.0   3924.0  15/16
# 1     41.0    0.0      0.0   3416.0  15/16
# 2     49.0    1.0      0.0   4268.0  15/16
# 3     36.0    1.0      5.0   2985.0  15/16
# 4     26.0    2.0      4.0   1880.0  15/16
# ..     ...    ...      ...      ...    ...
# 436    6.0    1.0      0.0    239.0  19/20
# 437    2.0    0.0      0.0     35.0  19/20
# 438    3.0    1.0      0.0    134.0  19/20
# 439    4.0    0.0      0.0    232.0  19/20
# 440    NaN    NaN      NaN      NaN  19/20
#
# [2205 rows x 11 columns]

# %%
df_perf['firstinitial'] = df_perf['name'].astype(str).str[0]
df_perf['lastname'] = df_perf['name'].str.split(' ').str[1]
df_perf['short_name']=df_perf['firstinitial'].astype(str)+'. '+df_perf['lastname']
df_perf
# Out:
#      Unnamed: 0                 name  age  height position      current club  \
# 0             0      Aymeric Laporte   25   191.0        W   Manchester City
# 1             1          John Stones   25   188.0        W   Manchester City
# 2             2     Nicolás Otamendi   31   183.0        W   Manchester City
# 3             3       Benjamin Mendy   25   185.0        W   Manchester City
# 4             4  Oleksandr Zinchenko   22   175.0        W   Manchester City
# ..          ...                  ...  ...     ...      ...               ...
# 436         436      Oliver McBurnie   23   188.0       CF  Sheffield United
# 437         437          Lys Mousset   23   184.0       CF  Sheffield United
# 438         438          Billy Sharp   33   175.0       CF  Sheffield United
# 439         439     David McGoldrick   31   184.0       CF  Sheffield United
# 440         440          Leon Clarke   34   188.0       CF  Sheffield United
#
#      games  goals  assists  minutes   year firstinitial    lastname  \
# 0     45.0    5.0      2.0   3924.0  15/16            A     Laporte
# 1     41.0    0.0      0.0   3416.0  15/16            J      Stones
# 2     49.0    1.0      0.0   4268.0  15/16            N    Otamendi
# 3     36.0    1.0      5.0   2985.0  15/16            B       Mendy
# 4     26.0    2.0      4.0   1880.0  15/16            O   Zinchenko
# ..     ...    ...      ...      ...    ...          ...         ...
# 436    6.0    1.0      0.0    239.0  19/20            O    McBurnie
# 437    2.0    0.0      0.0     35.0  19/20            L     Mousset
# 438    3.0    1.0      0.0    134.0  19/20            B       Sharp
# 439    4.0    0.0      0.0    232.0  19/20            D  McGoldrick
# 440    NaN    NaN      NaN      NaN  19/20            L      Clarke
#
#         short_name
# 0       A. Laporte
# 1        J. Stones
# 2      N. Otamendi
# 3         B. Mendy
# 4     O. Zinchenko
# ..             ...
# 436    O. McBurnie
# 437     L. Mousset
# 438       B. Sharp
# 439  D. McGoldrick
# 440      L. Clarke
#
# [2205 rows x 14 columns]

# %%
df_perf = df_perf.drop(columns=['Unnamed: 0','firstinitial', 'lastname'])
df_perf = df_perf.dropna()
df_perf
# Out:
#                     name  age  height position      current club  games  \
# 0        Aymeric Laporte   25   191.0        W   Manchester City   45.0
# 1            John Stones   25   188.0        W   Manchester City   41.0
# 2       Nicolás Otamendi   31   183.0        W   Manchester City   49.0
# 3         Benjamin Mendy   25   185.0        W   Manchester City   36.0
# 4    Oleksandr Zinchenko   22   175.0        W   Manchester City   26.0
# ..                   ...  ...     ...      ...               ...    ...
# 434      Callum Robinson   24   178.0        W  Sheffield United    4.0
# 436      Oliver McBurnie   23   188.0       CF  Sheffield United    6.0
# 437          Lys Mousset   23   184.0       CF  Sheffield United    2.0
# 438          Billy Sharp   33   175.0       CF  Sheffield United    3.0
# 439     David McGoldrick   31   184.0       CF  Sheffield United    4.0
#
#      goals  assists  minutes   year     short_name
# 0      5.0      2.0   3924.0  15/16     A. Laporte
# 1      0.0      0.0   3416.0  15/16      J. Stones
# 2      1.0      0.0   4268.0  15/16    N. Otamendi
# 3      1.0      5.0   2985.0  15/16       B. Mendy
# 4      2.0      4.0   1880.0  15/16   O. Zinchenko
# ..     ...      ...      ...    ...            ...
# 434    1.0      0.0    256.0  19/20    C. Robinson
# 436    1.0      0.0    239.0  19/20    O. McBurnie
# 437    0.0      0.0     35.0  19/20     L. Mousset
# 438    1.0      0.0    134.0  19/20       B. Sharp
# 439    0.0      0.0    232.0  19/20  D. McGoldrick
#
# [2012 rows x 11 columns]

# %%
df_perf['current club'].value_counts()
# Out:
# Watford FC                 125
# Leicester City             119
# Newcastle United           114
# Sheffield United           113
# AFC Bournemouth            107
# Wolverhampton Wanderers    105
# Norwich City               104
# Tottenham Hotspur          104
# West Ham United            100
# Everton FC                  99
# Manchester United           98
# Crystal Palace              98
# Burnley FC                  97
# Brighton & Hove Albion      96
# Southampton FC              96
# Aston Villa                 89
# Liverpool FC                89
# Arsenal FC                  89
# Chelsea FC                  87
# Manchester City             83
# Name: current club, dtype: int64

# %%
path = r'C:\Users\aaron\prem_league_analytics\data\ml_analysis\ '
df_perf.to_csv(path+'perf.csv')

# %%
df_perf.dtypes
# Out:
# name             object
# age               int64
# height          float64
# position         object
# current club     object
# games           float64
# goals           float64
# assists         float64
# minutes         float64
# year             object
# short_name       object
# dtype: object

# %%
order_goals = df_perf.groupby(by=['current club'])['goals'].median().sort_values(ascending=False).index

# %%
#Historical trends from 
ax=sns.catplot(x="current club", y="goals", kind="box", order = order_goals, data=df_perf)
ax.fig.set_size_inches(25,20)
ax.set_xticklabels(rotation=90)
plt.title('Goals by Club from 2015-2019')
plt.show()
