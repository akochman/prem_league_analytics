# %%
import urllib
import requests
from bs4 import BeautifulSoup as bs
import re
import pandas as pd
from time import time, sleep

# %%
BASE_URL = "https://www.transfermarkt.com"

class League:
	def __init__( self, name, url, scraper):
		self.LeagueName = name
		soup = scraper(url)
		teamsTable = soup.find("table", class_="items")
		teamUrls = teamsTable.find_all("a", class_="vereinprofil_tooltip", id=re.compile("\d+"))[::2]
		teamUrls = [BASE_URL + teamUrl["href"] for teamUrl in teamUrls]
		self.TeamsData = [ Team(teamUrl, self.LeagueName, scraper) for teamUrl in teamUrls]

# %%
BASE_URL = "https://www.transfermarkt.com"


class Team:
	def __init__( self, url, name, scraper):
		self.LeagueName = name
		soup = scraper(url)
		#reading player table and filtering for offensive players
		playerTable = soup.find("table", class_="items")
		players = playerTable.find_all("a", class_="spielprofil_tooltip")[::2]
# 		offensivePlayers = filter( Team.isStrikerOrWinger, players)
		PlayersUrls = [BASE_URL + player["href"] for player in players]
		#self.PlayerData = [PlayerProfile( playerUrl, scraper) for playerUrl in offensivePlayersUrls]
		self.PlayersData = []
		for playerUrl in PlayersUrls:
			try:
				NewPlayerProfile = PlayerProfile( playerUrl, scraper)
				NewPlayerProfile.PlayerData["current league"] = self.LeagueName
				self.PlayersData.append( NewPlayerProfile)
			except:
				continue


	@staticmethod
	def isStrikerOrWinger( player):
		position = player.find_next("tr").text.strip().lower()
		return "wing" in position or "centre-forward" in position

# %%
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

CURRENT_YEAR = 19
N_SEASON_HISTORY = 5


class PlayerProfile:
	def __init__(self, playerUrl, pageScraper):
		urlPerfPage = playerUrl.replace("profil","leistungsdatendetails")
		soup = pageScraper( playerUrl)

		playerAttributes = {}

		#scraping profile page information
		playerAttributes["name"] = soup.find("div", class_="dataMain").find("h1").text
		StoredAttributes = ["Age:", "Height:", "Nationality:", "Position:", "Foot:", "Current club:"]
		for entry in soup.find("table", class_="auflistung").find_all("th"):
			key = entry.text.strip()
			val = entry.find_next_sibling().text
			if key in StoredAttributes:
				playerAttributes[ key[:-1].lower()] = val.strip()
		#cleaning some entries
		if "height" in playerAttributes:
			#converting height in meters str to cm int 
			meter, centimeters = re.search("(\d),(\d+)",playerAttributes["height"]).groups()
			playerAttributes["height"] = int(meter)*100 + int(centimeters)
		if "nationality" in playerAttributes:
			if "\xa0" in playerAttributes["nationality"]:
				playerAttributes["nationality"] = playerAttributes["nationality"].replace("\xa0", " ")
		if "position" in playerAttributes:
			playerAttributes["position"] = "CF" if "Centre-Forward" in playerAttributes["position"] else "W"
		if "age" in playerAttributes:
			playerAttributes["age"] = int( playerAttributes["age"])

		#scraping performance page information
		soup = pageScraper(urlPerfPage)
		performanceColumns = ("season", "games", "goals", "assists", "minutes")
		performanceRows = pd.DataFrame( {col:[] for col in performanceColumns})
		for row in soup.find("div", class_="responsive-table").find("tbody").find_all("tr"):
			#try:
			rowContents = PlayerProfile.readRow( row)
			#except:
			#	 print( row)
			#else:
			#	 pass
			year = rowContents[0]
			if re.match( "\d{4}", year):
				year = int( year[2:])
				year = "%02d/%02d" %(year-1, year)
				rowContents[0] = year
			if not re.match( "\d{2}\/\d{2}", year):
				raise ValueError("Wrong format for played year")
			if int( year[:2]) < CURRENT_YEAR - N_SEASON_HISTORY:
				break
			#print( rowContents)
			performanceRows = performanceRows.append( {col:val for col, val in zip(performanceColumns, rowContents)}, ignore_index=True)
		performanceDF = performanceRows.groupby("season").sum()
		#converting to serie
		performanceSeries = pd.Series( {"%s %s" %(row, col): performanceDF[col][row] for row in performanceDF.index for col in performanceDF.columns})
		
		self.PlayerData = pd.Series( playerAttributes).append( performanceSeries)
		print( "\t%s done" %self.PlayerData["name"])
		
	def __str__(self):
		return "Performance profile for %s" % self.PlayerData["name"]

	def __repr__(self):
		return "< profile of %s >" % self.PlayerData["name"]

	@staticmethod
	def readRow( row):
		cells = row.find_all( "td")
		cells = list( map( lambda x : x.text.strip(), cells))
		year = cells[0]
		games_played = cells[4]
		goals_scored = cells[6]
		assists = cells[7]
		minutes_played = cells[-1]
		games_played = int(games_played) if games_played != "-" else 0
		goals_scored = int(goals_scored) if goals_scored != "-" else 0
		assists = int(assists) if assists != "-" else 0
		minutes_played = int( minutes_played[:-1].replace(".","")) if minutes_played != "-" else 0
		return [year, games_played, goals_scored, assists, minutes_played]

# %%
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

CURRENT_YEAR = 19
N_SEASON_HISTORY = 5


class PlayerProfile:
	def __init__(self, playerUrl, pageScraper):
		soup = pageScraper( playerUrl)
        
		playerAttributes = {}
        
		#scraping profile page information
		playerAttributes["name"] = soup.find("div", class_="dataMain").find("h1").text
		StoredAttributes = ["Age:", "Height:", "Nationality:", "Position:", "Foot:", "Current club:"]
		for entry in soup.find("table", class_="auflistung").find_all("th"):
			key = entry.text.strip()
			val = entry.find_next_sibling().text
			if key in StoredAttributes:
				playerAttributes[ key[:-1].lower()] = val.strip()
		#cleaning some entries
		if "height" in playerAttributes:
			#converting height in meters str to cm int 
			meter, centimeters = re.search("(\d),(\d+)",playerAttributes["height"]).groups()
			playerAttributes["height"] = int(meter)*100 + int(centimeters)
		if "nationality" in playerAttributes:
			if "\xa0" in playerAttributes["nationality"]:
				playerAttributes["nationality"] = playerAttributes["nationality"].replace("\xa0", " ")
		if "position" in playerAttributes:
			playerAttributes["position"] = "CF" if "Centre-Forward" in playerAttributes["position"] else "W"
		if "age" in playerAttributes:
			playerAttributes["age"] = int( playerAttributes["age"])
        
		#scraping transfer page information
		TransferColumns = ("season", "date", "left", "joined", "mv", "fee")
		TransferRows = pd.DataFrame( {col:[] for col in TransferColumns})
		for row in soup.find("div", class_="responsive-table").find("tbody").find_all("tr", class_='zeile-transfer'):
			#try:
			rowContents = PlayerProfile.readRow( row)
			print( rowContents)
			TransferRows = TransferRows.append( {col:val for col, val in zip(TransferColumns, rowContents)}, ignore_index=True)
		TransferDF = TransferRows.groupby("season").sum()
		#converting to serie
		TransferSeries = pd.Series( {"%s %s" %(row, col): TransferDF[col][row] for row in TransferDF.index for col in TransferDF.columns})
		
		self.PlayerData = pd.Series( playerAttributes).append( TransferSeries)
		print( "\t%s done" %self.PlayerData["name"])
		
	def __str__(self):
		return "Transfer profile for %s" % self.PlayerData["name"]

	def __repr__(self):
		return "< profile of %s >" % self.PlayerData["name"]

	@staticmethod
	def readRow( row):
		cells = row.find_all( "td")
		cells = list( map( lambda x : x.text.strip(), cells))
		year = cells[0]
		date = cells[1]
		left = cells[5]
		joined = cells[9]
		mv = cells[10]
		fee = cells[11]
		mv = str(mv) if mv != "-" else 0
		fee = str(fee) if fee != "-" else 0
		return [year, date, left, joined, mv, fee]

# %%
N_LEAGUES = 1 #keeping the top N leagues
LEAGUES_URL = "https://www.transfermarkt.com/wettbewerbe/europa/wettbewerbe"
BASE_URL = "https://www.transfermarkt.com"

DELAY_BETWEEN_QUERIES = 0 #min delay in seconds spacing http queries
class PageScraper():
    def __init__(self ):
        self.opener = urllib.request.build_opener()
        self.opener.addheaders = [('User-agent', 'Mozilla/5.0')]
        self.lastQuery = -float("inf")
    def readUrl( self, url_):
        presentTime = time() - self.lastQuery - DELAY_BETWEEN_QUERIES
        if presentTime < 0:
            sleep( abs(presentTime))
        inData = self.opener.open(url_)
        content = inData.read()
        self.lastQuery = time()
        return bs(content, "html.parser")
    def __call__( self, url_):
        return self.readUrl( url_)


if __name__ == "__main__":
	scraper = PageScraper()
	soup = scraper( LEAGUES_URL)
	LeagueTables = soup.find("table", class_="items").find("tbody")
	Leagues = LeagueTables.find_all("a", href=re.compile("wettbewerb/[A-Z]{2}1"), title=re.compile("\w"))
	Leagues = Leagues[:N_LEAGUES]
	LeagueUrlDic = { league.text : BASE_URL + league["href"] for league in Leagues}
	LeaguesData = []
	for leagueName, leagueUrl in LeagueUrlDic.items():
		print( "Scraping the %s..." %leagueName)
		LeaguesData.append( League( leagueName, leagueUrl, scraper))

	#flattening all players information to pandas.DataFrame and exporting to csv
	PlayerProfiles = [player.PlayerData for league in LeaguesData for team in league.TeamsData for player in team.PlayersData]
	df = pd.DataFrame( PlayerProfiles)
	df.to_csv("transfer.csv", index=False)
# Out:
# Scraping the Premier League...
# ['17/18', 'Jul 1, 2017', 'Benfica', 'Man City', '22,00 mil. €', '40,00 mil. €']
# ['15/16', 'Jul 1, 2015', 'Rio Ave FC', 'Benfica', '1,20 mil. €', '500 thousand €']
# ['12/13', 'Jul 1, 2012', 'GD Ribeirão', 'Rio Ave FC', 0, 'Available for free transfer']
# ['11/12', 'Jul 1, 2011', 'Benfica U19', 'GD Ribeirão', 0, 'Available for free transfer']
# ['10/11', 'Jul 1, 2010', 'Benfica U17', 'Benfica U19', 0, 0]
# ['09/10', 'Jan 1, 2010', 'São Paulo U17', 'Benfica U17', 0, '?']
# 	Ederson done
# ['16/17', 'Aug 25, 2016', 'FC Barcelona', 'Man City', '15,00 mil. €', '18,00 mil. €']
# ['14/15', 'Jul 1, 2014', 'Real Sociedad', 'FC Barcelona', '4,00 mil. €', '12,00 mil. €']
# ['06/07', 'Jul 1, 2006', 'Colo Colo', 'Real Sociedad', 0, '1,20 mil. €']
# ['01/02', 'Jan 1, 2002', 'Colo Colo U19', 'Colo Colo', 0, 0]
# 	Claudio Bravo done
# ['19/20', 'Aug 8, 2019', 'Derby', 'Man City', '2,00 mil. €', 'Loan']
# ['15/16', 'Jul 1, 2015', 'Wigan', 'Derby', '2,00 mil. €', '?']
# ['13/14', 'Jul 4, 2013', 'Bursaspor', 'Wigan', '4,20 mil. €', '820 thousand €']
# ['11/12', 'Jul 1, 2011', 'West Brom', 'Bursaspor', '3,50 mil. €', '2,20 mil. €']
# ['08/09', 'Jul 18, 2008', 'Liverpool', 'West Brom', '6,00 mil. €', '4,00 mil. €']
# ['07/08', 'Jun 30, 2008', 'Aston Villa', 'Liverpool', '5,25 mil. €', 'End of loan']
# ['07/08', 'Aug 10, 2007', 'Liverpool', 'Aston Villa', '2,50 mil. €', 'Loan']
# ['06/07', 'Jul 8, 2007', 'Charlton', 'Liverpool', '2,50 mil. €', 'End of loan']
# ['06/07', 'Aug 16, 2006', 'Liverpool', 'Charlton', '1,75 mil. €', 'Loan']
# ['05/06', 'May 1, 2006', 'Sheff Wed', 'Liverpool', '1,75 mil. €', 'End of loan']
# ['05/06', 'Mar 10, 2006', 'Liverpool', 'Sheff Wed', '1,75 mil. €', 'Loan']
# ['04/05', 'Jan 21, 2005', 'Leeds', 'Liverpool', '750 thousand €', '1,40 mil. €']
# ['03/04', 'Jul 1, 2003', 'Leeds U18', 'Leeds', 0, 0]
# 	Scott Carson done
# ['17/18', 'Jan 30, 2018', 'Athletic', 'Man City', '25,00 mil. €', '65,00 mil. €']
# ['12/13', 'Dec 17, 2012', 'Bilbao Athletic', 'Athletic', '600 thousand €', 0]
# ['12/13', 'Jul 1, 2012', 'CD Basconia', 'Bilbao Athletic', 0, 0]
# ['11/12', 'Jul 1, 2011', 'Bilbao U19', 'CD Basconia', 0, 0]
# 	Aymeric Laporte done
# ['16/17', 'Aug 9, 2016', 'Everton', 'Man City', '28,00 mil. €', '55,60 mil. €']
# ['12/13', 'Jan 31, 2013', 'Barnsley FC', 'Everton', '100 thousand €', '3,50 mil. €']
# ['11/12', 'Jul 1, 2011', 'Barnsley U18', 'Barnsley FC', 0, 0]
# 	John Stones done
# ['15/16', 'Aug 20, 2015', 'Valencia', 'Man City', '25,00 mil. €', '44,60 mil. €']
# ['14/15', 'Jul 1, 2014', 'FC Porto', 'Valencia', '12,00 mil. €', '12,00 mil. €']
# ['13/14', 'Jun 30, 2014', 'Atlético-MG', 'FC Porto', '12,00 mil. €', 'End of loan']
# ['13/14', 'Jan 31, 2014', 'FC Porto', 'Atlético-MG', '13,00 mil. €', 'Loan']
# ['10/11', 'Aug 31, 2010', 'Vélez Sarsfield', 'FC Porto', '5,00 mil. €', '4,00 mil. €']
# ['08/09', 'Jan 1, 2009', 'Vélez II', 'Vélez Sarsfield', '50 thousand €', 0]
# ['07/08', 'Jul 1, 2007', 'Vélez U20', 'Vélez II', 0, 0]
# 	Nicolás Otamendi done
# ['17/18', 'Jul 24, 2017', 'Monaco', 'Man City', '13,00 mil. €', '57,50 mil. €']
# ['16/17', 'Jul 1, 2016', 'Marseille', 'Monaco', '6,50 mil. €', '13,00 mil. €']
# ['13/14', 'Jul 9, 2013', 'AC Le Havre', 'Marseille', '2,00 mil. €', '4,00 mil. €']
# ['11/12', 'Jul 1, 2011', 'Le Havre U19', 'AC Le Havre', 0, 0]
# 	Benjamin Mendy done
# ['16/17', 'Jun 30, 2017', 'PSV Eindhoven', 'Man City', '4,50 mil. €', 'End of loan']
# ['16/17', 'Aug 26, 2016', 'Man City', 'PSV Eindhoven', '4,00 mil. €', 'Loan']
# ['16/17', 'Jul 4, 2016', 'Ufa', 'Man City', '4,00 mil. €', '2,00 mil. €']
# ['14/15', 'Feb 13, 2015', 'Career break', 'Ufa', 0, 0]
# ['14/15', 'Jul 1, 2014', 'Shakhtar U19', 'Career break', 0, 0]
# ['12/13', 'Jul 1, 2012', 'Shakhtar Donetsk U17', 'Shakhtar U19', 0, 0]
# 	Oleksandr Zinchenko done
# ['19/20', 'Jul 3, 2019', 'PSV Eindhoven', 'Man City', '16,00 mil. €', '12,00 mil. €']
# ['18/19', 'Jul 1, 2018', 'Man City U23', 'PSV Eindhoven', '3,00 mil. €', '5,50 mil. €']
# ['17/18', 'Jun 29, 2018', 'NAC Breda', 'Man City U23', '3,00 mil. €', 'End of loan']
# ['17/18', 'Jul 4, 2017', 'Man City U23', 'NAC Breda', '500 thousand €', 'Loan']
# ['16/17', 'Jun 30, 2017', 'RCD Mallorca', 'Man City U23', '500 thousand €', 'End of loan']
# ['16/17', 'Jan 31, 2017', 'Man City U23', 'RCD Mallorca', '300 thousand €', 'Loan']
# ['16/17', 'Jan 30, 2017', 'Girona', 'Man City U23', '300 thousand €', 'End of loan']
# ['16/17', 'Jan 1, 2017', 'Man City U23', 'Girona', 0, 'Loan']
# ['15/16', 'Oct 31, 2015', 'NYCFC', 'Man City U21', 0, 'End of loan']
# ['15/16', 'Jul 8, 2015', 'Man City U21', 'NYCFC', 0, 'Loan']
# ['14/15', 'Jul 1, 2014', 'Man City U18', 'Man City U21', 0, 0]
# ['13/14', 'Jul 3, 2013', 'Deportivo de La', 'Man City U18', 0, '4,50 mil. €']
# 	Angeliño done
# ['19/20', 'Aug 7, 2019', 'Juventus', 'Man City', '55,00 mil. €', '65,00 mil. €']
# ['18/19', 'Jul 1, 2018', 'Valencia', 'Juventus', '35,00 mil. €', '40,40 mil. €']
# ['17/18', 'Jun 30, 2018', 'Inter', 'Valencia', '35,00 mil. €', 'End of loan']
# ['17/18', 'Aug 22, 2017', 'Valencia', 'Inter', '20,00 mil. €', 'Loan']
# ['15/16', 'Jul 1, 2015', 'Benfica', 'Valencia', '5,00 mil. €', '15,00 mil. €']
# ['14/15', 'Jun 30, 2015', 'Valencia', 'Benfica', '2,00 mil. €', 'End of loan']
# ['14/15', 'Aug 20, 2014', 'Benfica', 'Valencia', '2,00 mil. €', 'Loan']
# ['14/15', 'Jul 1, 2014', 'Benfica B', 'Benfica', '2,00 mil. €', 0]
# ['12/13', 'Jan 1, 2013', 'Benfica U19', 'Benfica B', '1,00 mil. €', 0]
# ['11/12', 'Jan 1, 2011', 'Benfica U17', 'Benfica U19', 0, 0]
# ['09/10', 'Jul 1, 2009', 'Benfica U15', 'Benfica U17', 0, 0]
# 	João Cancelo done
# ['17/18', 'Jul 14, 2017', 'Spurs', 'Man City', '30,00 mil. €', '52,70 mil. €']
# ['10/11', 'May 31, 2011', 'Aston Villa', 'Spurs', '2,00 mil. €', 'End of loan']
# ['10/11', 'Jan 5, 2011', 'Spurs', 'Aston Villa', '2,00 mil. €', 'Loan']
# ['10/11', 'Dec 31, 2010', 'QPR', 'Spurs', '2,00 mil. €', 'End of loan']
# ['10/11', 'Sep 13, 2010', 'Spurs', 'QPR', '2,00 mil. €', 'Loan fee:235 thousand €']
# ['09/10', 'Feb 1, 2010', 'Sheffield Utd.', 'Spurs', '3,00 mil. €', 'End of loan']
# ['09/10', 'Aug 4, 2009', 'Spurs', 'Sheffield Utd.', '50 thousand €', 'Loan']
# ['09/10', 'Jul 22, 2009', 'Sheffield Utd.', 'Spurs', '50 thousand €', '5,90 mil. €']
# ['08/09', 'Jan 1, 2009', 'Northampt. Town', 'Sheffield Utd.', 0, 'End of loan']
# ['08/09', 'Nov 1, 2008', 'Sheffield Utd.', 'Northampt. Town', 0, 'Loan']
# ['08/09', 'Jul 1, 2008', 'Sheff Utd U18', 'Sheffield Utd.', 0, 0]
# 	Kyle Walker done
# ['19/20', 'Jul 4, 2019', 'Atlético Madrid', 'Man City', '80,00 mil. €', '70,00 mil. €']
# ['18/19', 'Jul 1, 2018', 'Villarreal', 'Atlético Madrid', '25,00 mil. €', '25,00 mil. €']
# ['16/17', 'Jul 1, 2016', 'Villarreal CF B', 'Villarreal', 0, 0]
# ['15/16', 'Jul 1, 2015', 'Villarreal U19', 'Villarreal CF B', 0, 0]
# ['13/14', 'Jul 1, 2013', 'Atlético Juv. B', 'Villarreal U19', 0, 'Available for free transfer']
# ['12/13', 'Jul 1, 2012', 'Atlético Youth', 'Atlético Juv. B', 0, 0]
# ['07/08', 'Jul 1, 2007', 'CF Rayo Majadaho', 'Atlético Youth', 0, 'Available for free transfer']
# 	Rodri done
# ['13/14', 'Jul 1, 2013', 'Shakhtar D.', 'Man City', '32,00 mil. €', '40,00 mil. €']
# ['05/06', 'Jul 1, 2005', 'Atlético-PR', 'Shakhtar D.', '500 thousand €', '7,80 mil. €']
# ['02/03', 'Jul 1, 2002', 'Atlético-PR U20', 'Atlético-PR', 0, 0]
# 	Fernandinho done
# ['16/17', 'Jul 1, 2016', 'Bor. Dortmund', 'Man City', '30,00 mil. â‚¬', '27,00 mil. â‚¬']
# ['11/12', 'Jul 1, 2011', '1.FC Nuremberg', 'Bor. Dortmund', '6,50 mil. â‚¬', '5,50 mil. â‚¬']
# ['08/09', 'Feb 3, 2009', 'VfL Bochum U19', '1.FC Nuremberg', '100 thousand â‚¬', '850 thousand â‚¬']
# ['07/08', 'Jul 1, 2007', 'VfL Bochum U17', 'VfL Bochum U19', 0, 0]
# ['05/06', 'Jul 1, 2005', 'SSV Buer Yth.', 'VfL Bochum U17', 0, 'Available for free transfer']
# ['04/05', 'Jul 1, 2004', 'HeÃŸler 06 Yth.', 'SSV Buer Yth.', 0, 'Available for free transfer']
# ['99/00', 'Jul 1, 1999', 'Schalke 04 Yth.', 'HeÃŸler 06 Yth.', 0, 'Available for free transfer']
# ['98/99', 'Jul 1, 1998', 'HeÃŸler 06 Yth.', 'Schalke 04 Yth.', 0, 'Available for free transfer']
# 	Ilkay GÃ¼ndogan done
# ['17/18', 'Jul 1, 2017', 'Man City U18', 'Man City', 0, 0]
# ['16/17', 'Jul 1, 2016', 'Man City Youth', 'Man City U18', 0, 0]
# 	Phil Foden done
# ['15/16', 'Aug 30, 2015', 'VfL Wolfsburg', 'Man City', '45,00 mil. €', '76,00 mil. €']
# ['13/14', 'Jan 18, 2014', 'Chelsea', 'VfL Wolfsburg', '15,00 mil. €', '22,00 mil. €']
# ['12/13', 'Jun 30, 2013', 'Werder Bremen', 'Chelsea', '10,00 mil. €', 'End of loan']
# ['12/13', 'Aug 2, 2012', 'Chelsea', 'Werder Bremen', '9,00 mil. €', 'Loan fee:450 thousand €']
# ['11/12', 'Jun 30, 2012', 'KRC Genk', 'Chelsea', '9,00 mil. €', 'End of loan']
# ['11/12', 'Feb 1, 2012', 'Chelsea', 'KRC Genk', '9,00 mil. €', 'Loan']
# ['11/12', 'Jan 31, 2012', 'KRC Genk', 'Chelsea', '9,00 mil. €', '8,00 mil. €']
# ['08/09', 'Jul 1, 2008', 'KRC Genk U19', 'KRC Genk', 0, 0]
# ['07/08', 'Jul 1, 2007', 'KRC Genk U17', 'KRC Genk U19', 0, 0]
# ['06/07', 'Jul 1, 2006', 'KRC Genk Youth', 'KRC Genk U17', 0, 0]
# ['05/06', 'Jul 1, 2005', 'KAA Gent Youth', 'KRC Genk Youth', 0, 'Available for free transfer']
# 	Kevin De Bruyne done
# ['10/11', 'Jul 14, 2010', 'Valencia', 'Man City', '32,00 mil. €', '28,75 mil. €']
# ['05/06', 'Jun 30, 2006', 'Celta de Vigo', 'Valencia', '800 thousand €', 'End of loan']
# ['05/06', 'Aug 8, 2005', 'Valencia', 'Celta de Vigo', 0, 'Loan']
# ['04/05', 'Jun 30, 2005', 'SD Eibar', 'Valencia', 0, 'End of loan']
# ['04/05', 'Aug 2, 2004', 'Valencia', 'SD Eibar', 0, 'Loan']
# ['04/05', 'Jul 1, 2004', 'Valencia B', 'Valencia', 0, 0]
# ['03/04', 'Jul 1, 2003', 'Valencia U19', 'Valencia B', 0, 0]
# ['02/03', 'Jul 1, 2002', 'Valencia CF You', 'Valencia U19', 0, 0]
# 	David Silva done
# ['15/16', 'Jul 14, 2015', 'Liverpool', 'Man City', '40,00 mil. €', '63,70 mil. €']
# ['12/13', 'Jul 1, 2012', 'Liverpool U18', 'Liverpool', 0, 0]
# ['09/10', 'Feb 16, 2010', 'QPR U18', 'Liverpool U18', 0, '700 thousand €']
# 	Raheem Sterling done
# ['16/17', 'Aug 2, 2016', 'FC Schalke 04', 'Man City', '30,00 mil. €', '50,50 mil. €']
# ['15/16', 'Jul 1, 2015', 'Schalke 04 U19', 'FC Schalke 04', '4,00 mil. €', 0]
# ['13/14', 'Jul 1, 2013', 'Schalke 04 U17', 'Schalke 04 U19', 0, 0]
# ['11/12', 'Jul 1, 2011', 'Leverkusen Yth.', 'Schalke 04 U17', 0, 'Available for free transfer']
# ['08/09', 'Jul 1, 2008', 'Schalke 04 Yth.', 'Leverkusen Yth.', 0, 'Available for free transfer']
# ['05/06', 'Jul 1, 2005', 'Wattensch. Yth.', 'Schalke 04 Yth.', 0, 'Available for free transfer']
# 	Leroy Sané done
# ['17/18', 'Jul 1, 2017', 'Monaco', 'Man City', '40,00 mil. €', '50,00 mil. €']
# ['14/15', 'Jan 20, 2015', 'Benfica', 'Monaco', '3,50 mil. €', '15,75 mil. €']
# ['14/15', 'Jan 19, 2015', 'Monaco', 'Benfica', '3,50 mil. €', 'End of loan']
# ['14/15', 'Aug 7, 2014', 'Benfica', 'Monaco', '2,50 mil. €', 'Loan']
# ['14/15', 'Jul 1, 2014', 'Benfica B', 'Benfica', '2,50 mil. €', 0]
# ['13/14', 'Jul 1, 2013', 'Benfica U19', 'Benfica B', 0, 0]
# ['11/12', 'Jul 1, 2011', 'Benfica U17', 'Benfica U19', 0, 0]
# ['09/10', 'Jul 1, 2009', 'Benfica U15', 'Benfica U17', 0, 0]
# ['07/08', 'Jul 1, 2007', 'SL Benfica Yout', 'Benfica U15', 0, 0]
# 	Bernardo Silva done
# ['18/19', 'Jul 10, 2018', 'Leicester', 'Man City', '50,00 mil. €', '67,80 mil. €']
# ['13/14', 'Jan 11, 2014', 'AC Le Havre', 'Leicester', '750 thousand €', '500 thousand €']
# ['11/12', 'Jul 1, 2011', 'Le Havre B', 'AC Le Havre', 0, 0]
# ['10/11', 'Jul 1, 2010', 'Quimper FC', 'Le Havre B', 0, 'Available for free transfer']
# 	Riyad Mahrez done
# ['16/17', 'Jan 1, 2017', 'Palmeiras', 'Man City', '16,00 mil. €', '32,00 mil. €']
# ['14/15', 'Jan 1, 2015', 'Palmeiras U17', 'Palmeiras', 0, 0]
# 	Gabriel Jesus done
# ['11/12', 'Jul 28, 2011', 'Atlético Madrid', 'Man City', '36,00 mil. €', '40,00 mil. €']
# ['06/07', 'Jul 1, 2006', 'Independiente', 'Atlético Madrid', '5,00 mil. €', '21,70 mil. €']
# ['04/05', 'Jul 1, 2004', "Indep'te U20", 'Independiente', 0, 0]
# 	Sergio Agüero done
# ['18/19', 'Jul 19, 2018', 'AS Roma', 'Liverpool', '60,00 mil. €', '62,50 mil. €']
# ['16/17', 'Jul 6, 2016', 'Internacional', 'AS Roma', '7,00 mil. €', '8,00 mil. €']
# ['12/13', 'Jan 1, 2013', 'Inter B', 'Internacional', '150 thousand €', 0]
# ['11/12', 'Jan 1, 2012', 'Inter U20', 'Inter B', 0, 0]
# 	Alisson done
# ['19/20', 'Aug 5, 2019', 'West Ham', 'Liverpool', '3,50 mil. €', 'Available for free transfer']
# ['13/14', 'Jul 1, 2013', 'Real Betis', 'West Ham', '2,00 mil. €', 'Available for free transfer']
# ['12/13', 'Jul 1, 2012', 'Betis B', 'Real Betis', 0, 0]
# ['06/07', 'Jul 1, 2006', 'Betis U19', 'Betis B', 0, 0]
# 	Adrián done
# ['19/20', 'Aug 12, 2019', 'Without Club', 'Liverpool', '250 thousand €', 0]
# ['19/20', 'Jul 1, 2019', 'Middlesbrough', 'Without Club', '250 thousand €', 0]
# ['18/19', 'Mar 29, 2019', 'Rochdale', 'Middlesbrough', '250 thousand €', 'End of loan']
# ['18/19', 'Feb 7, 2019', 'Middlesbrough', 'Rochdale', '250 thousand €', 'Loan']
# ['18/19', 'Aug 2, 2018', 'Leeds', 'Middlesbrough', '350 thousand €', 'Available for free transfer']
# ['17/18', 'Aug 27, 2017', 'Wolves', 'Leeds', '500 thousand €', 'Available for free transfer']
# ['16/17', 'Jul 1, 2016', 'Fulham', 'Wolves', '500 thousand €', '300 thousand €']
# ['15/16', 'Jul 1, 2015', 'Bolton', 'Fulham', '500 thousand €', 'Available for free transfer']
# ['12/13', 'Jul 17, 2012', 'Leeds', 'Bolton', '500 thousand €', '320 thousand €']
# ['11/12', 'Jul 25, 2011', 'Preston NE', 'Leeds', '700 thousand €', '325 thousand €']
# ['06/07', 'Nov 30, 2006', 'Swindon Town', 'Preston NE', '300 thousand €', 'End of loan']
# ['06/07', 'Nov 3, 2006', 'Preston NE', 'Swindon Town', '300 thousand €', 'Loan']
# ['05/06', 'Nov 6, 2005', 'Wycombe', 'Preston NE', '400 thousand €', 'End of loan']
# ['05/06', 'Oct 6, 2005', 'Preston NE', 'Wycombe', '400 thousand €', 'Loan']
# ['02/03', 'Mar 17, 2003', 'Blackpool', 'Preston NE', 0, 'End of loan']
# ['02/03', 'Feb 7, 2003', 'Preston NE', 'Blackpool', 0, 'Loan']
# ['02/03', 'Dec 27, 2002', 'Darlington', 'Preston NE', 0, 'End of loan']
# ['02/03', 'Dec 20, 2002', 'Preston NE', 'Darlington', 0, 'Loan']
# ['02/03', 'Jul 1, 2002', 'Preston U18', 'Preston NE', 0, 0]
# 	Andy Lonergan done
# ['17/18', 'Jan 1, 2018', 'Southampton', 'Liverpool', '30,00 mil. €', '84,65 mil. €']
# ['15/16', 'Sep 1, 2015', 'Celtic', 'Southampton', '5,00 mil. €', '15,70 mil. €']
# ['13/14', 'Jul 1, 2013', 'FC Groningen', 'Celtic', '3,00 mil. €', '3,00 mil. €']
# ['11/12', 'Jul 1, 2011', 'Gron./Cam. U21', 'FC Groningen', '250 thousand €', 0]
# ['10/11', 'Jul 1, 2010', 'Willem II/RKC-19', 'FC Groning. U21', 0, 'Available for free transfer']
# ['08/09', 'Jul 1, 2008', 'Willem II U17', 'Willem II U19', 0, 0]
# ['06/07', 'Jul 1, 2006', 'Willem II Youth', 'Willem II U17', 0, 0]
# 	Virgil van Dijk done
# ['15/16', 'Jul 1, 2015', 'Charlton', 'Liverpool', '2,50 mil. €', '4,90 mil. €']
# ['14/15', 'Jul 1, 2014', 'Charlton U18', 'Charlton', 0, 0]
# 	Joe Gomez done
# ['16/17', 'Jul 1, 2016', 'FC Schalke 04', 'Liverpool', '18,00 mil. €', 'Available for free transfer']
# ['09/10', 'Nov 1, 2009', 'Schalke 04 U19', 'FC Schalke 04', 0, 0]
# ['08/09', 'Jul 1, 2008', 'Schalke 04 U17', 'Schalke 04 U19', 0, 0]
# ['06/07', 'Jul 1, 2006', 'Schalke 04 Yth.', 'Schalke 04 U17', 0, 0]
# ['00/01', 'Jul 1, 2000', 'VfL Bochum Yth.', 'Schalke 04 Yth.', 0, 'Available for free transfer']
# ['98/99', 'Jul 1, 1998', 'SC Weitmar Yth.', 'VfL Bochum Yth.', 0, 'Available for free transfer']
# 	Joel Matip done
# ['14/15', 'Jul 27, 2014', 'Southampton', 'Liverpool', '12,00 mil. €', '25,30 mil. €']
# ['13/14', 'Jul 1, 2013', 'Olympique Lyon', 'Southampton', '7,00 mil. €', '10,00 mil. €']
# ['09/10', 'Jan 13, 2010', 'Dinamo Zagreb', 'Olympique Lyon', '2,50 mil. €', '8,00 mil. €']
# ['07/08', 'Jun 30, 2008', 'Inter Zapresic', 'Dinamo Zagreb', '1,10 mil. €', 'End of loan']
# ['06/07', 'Jul 17, 2006', 'Dinamo Zagreb', 'Inter Zapresic', '800 thousand €', 'Loan']
# ['05/06', 'Jan 1, 2006', 'Din. Zagreb U17', 'Dinamo Zagreb', 0, 0]
# 	Dejan Lovren done
# ['17/18', 'Jul 21, 2017', 'Hull City', 'Liverpool', '7,00 mil. €', '9,00 mil. €']
# ['14/15', 'Jul 29, 2014', 'Dundee United', 'Hull City', '600 thousand €', '3,60 mil. €']
# ['13/14', 'Jul 1, 2013', "Queen's Park", 'Dundee United', 0, 'Available for free transfer']
# ['12/13', 'Jul 1, 2012', "Queen's P. U20", "Queen's Park", 0, 0]
# 	Andrew Robertson done
# ['16/17', 'Jul 1, 2016', 'Liverpool U18', 'Liverpool', 0, 0]
# ['15/16', 'Jul 1, 2015', 'Liverpool Youth', 'Liverpool U18', 0, 0]
# 	Trent Alexander-Arnold done
# ['18/19', 'May 31, 2019', 'Bournemouth', 'Liverpool', '15,00 mil. €', 'End of loan']
# ['18/19', 'Jan 4, 2019', 'Liverpool', 'Bournemouth', '15,00 mil. €', 'Loan']
# ['15/16', 'Jul 1, 2015', 'Southampton', 'Liverpool', '17,00 mil. €', '17,70 mil. €']
# ['12/13', 'Jul 18, 2012', 'Crystal Palace', 'Southampton', '2,00 mil. €', '3,20 mil. €']
# ['08/09', 'Jul 1, 2008', 'Palace U18', 'Crystal Palace', 0, 0]
# 	Nathaniel Clyne done
# ['18/19', 'Jul 1, 2018', 'Monaco', 'Liverpool', '45,00 mil. €', '45,00 mil. €']
# ['15/16', 'Jul 1, 2015', 'Rio Ave FC', 'Monaco', '8,00 mil. €', '6,00 mil. €']
# ['14/15', 'Jun 30, 2015', 'Monaco', 'Rio Ave FC', '8,00 mil. €', 'End of loan']
# ['13/14', 'Jul 19, 2013', 'Rio Ave FC', 'Monaco', '2,50 mil. €', 'Loan']
# ['12/13', 'Jun 30, 2013', 'RM Castilla', 'Rio Ave FC', '2,50 mil. €', 'End of loan']
# ['12/13', 'Jul 19, 2012', 'Rio Ave FC', 'RM Castilla', 0, 'Loan']
# ['12/13', 'Jul 1, 2012', 'Fluminense U20', 'Rio Ave FC', 0, '510 thousand €']
# 	Fabinho done
# ['16/17', 'Jul 22, 2016', 'Newcastle', 'Liverpool', '20,00 mil. €', '27,50 mil. €']
# ['15/16', 'Jul 11, 2015', 'PSV Eindhoven', 'Newcastle', '15,00 mil. €', '20,00 mil. €']
# ['11/12', 'Jul 1, 2011', 'Feyenoord', 'PSV Eindhoven', '6,50 mil. €', '5,00 mil. €']
# ['07/08', 'Jul 1, 2007', 'Feyenoord U19', 'Feyenoord', 0, 0]
# ['06/07', 'Jul 1, 2006', 'Feyenoord U17', 'Feyenoord U19', 0, 0]
# ['05/06', 'Jul 1, 2005', 'Feyenoord Youth', 'Feyenoord U17', 0, 0]
# ['04/05', 'Jul 1, 2004', 'Sparta Youth', 'Feyenoord Youth', 0, 'Available for free transfer']
# 	Georginio Wijnaldum done
# ['18/19', 'Jul 1, 2018', 'RB Leipzig', 'Liverpool', '65,00 mil. €', '60,00 mil. €']
# ['16/17', 'Jul 1, 2016', 'RB Salzburg', 'RB Leipzig', '11,00 mil. €', '24,00 mil. €']
# ['14/15', 'Jul 1, 2014', 'FC Istres', 'RB Salzburg', 0, '1,50 mil. €']
# ['13/14', 'Nov 27, 2013', 'Istres FC B', 'FC Istres', 0, 0]
# ['13/14', 'Aug 30, 2013', 'Horoya AC', 'Istres FC B', 0, '?']
# 	Naby Keïta done
# ['11/12', 'Jul 1, 2011', 'Sunderland', 'Liverpool', '8,50 mil. €', '18,00 mil. €']
# ['08/09', 'Apr 6, 2009', 'Coventry', 'Sunderland', '50 thousand €', 'End of loan']
# ['08/09', 'Jan 29, 2009', 'Sunderland', 'Coventry', '50 thousand €', 'Loan']
# ['08/09', 'Jul 1, 2008', 'Sunderland U18', 'Sunderland', 0, 0]
# ['06/07', 'Jul 1, 2006', 'Sunderland Yth.', 'Sunderland U18', 0, 0]
# 	Jordan Henderson done
# ['17/18', 'Aug 31, 2017', 'Arsenal', 'Liverpool', '22,00 mil. €', '38,00 mil. €']
# ['11/12', 'Aug 8, 2011', 'Southampton', 'Arsenal', '2,50 mil. €', '13,80 mil. €']
# ['10/11', 'Jul 1, 2010', 'Southampton U18', 'Southampton', '50 thousand €', 0]
# ['09/10', 'Jul 1, 2009', 'Southampton Yth', 'Southampton U18', 0, 0]
# 	Alex Oxlade-Chamberlain done
# ['15/16', 'Jul 1, 2015', 'Man City', 'Liverpool', '14,00 mil. €', 'Available for free transfer']
# ['10/11', 'Aug 17, 2010', 'Aston Villa', 'Man City', '20,00 mil. €', '22,00 mil. €']
# ['08/09', 'Aug 29, 2008', 'Newcastle', 'Aston Villa', '8,50 mil. €', '15,00 mil. €']
# ['05/06', 'May 8, 2006', 'Aston Villa', 'Newcastle', '4,70 mil. €', 'End of loan']
# ['05/06', 'Aug 31, 2005', 'Newcastle', 'Aston Villa', '5,50 mil. €', 'Loan']
# ['04/05', 'Jul 2, 2004', 'Leeds', 'Newcastle', 0, '7,40 mil. €']
# ['03/04', 'Oct 2, 2003', 'Swindon Town', 'Leeds', 0, 'End of loan']
# ['03/04', 'Sep 4, 2003', 'Leeds', 'Swindon Town', 0, 'Loan']
# ['02/03', 'Jul 1, 2002', 'Leeds U18', 'Leeds', 0, 0]
# 	James Milner done
# ['14/15', 'Jul 1, 2014', 'Southampton', 'Liverpool', '7,50 mil. €', '31,00 mil. €']
# ['07/08', 'Nov 1, 2007', 'Bournemouth', 'Southampton', '50 thousand €', 'End of loan']
# ['07/08', 'Oct 1, 2007', 'Southampton', 'Bournemouth', '50 thousand €', 'Loan']
# ['06/07', 'Jul 1, 2006', 'Southampton U18', 'Southampton', 0, 0]
# 	Adam Lallana done
# ['16/17', 'Jul 1, 2016', 'Southampton', 'Liverpool', '20,00 mil. €', '41,20 mil. €']
# ['14/15', 'Sep 1, 2014', 'RB Salzburg', 'Southampton', '7,50 mil. €', '23,00 mil. €']
# ['12/13', 'Aug 31, 2012', 'FC Metz', 'RB Salzburg', '500 thousand €', '4,00 mil. €']
# ['11/12', 'Jan 1, 2012', 'FC Metz B', 'FC Metz', 0, 0]
# ['11/12', 'Jul 1, 2011', 'Génération Foot', 'FC Metz B', 0, '?']
# 	Sadio Mané done
# ['17/18', 'Jul 1, 2017', 'AS Roma', 'Liverpool', '35,00 mil. €', '42,00 mil. €']
# ['16/17', 'Jul 1, 2016', 'Chelsea', 'AS Roma', '23,00 mil. €', '15,00 mil. €']
# ['15/16', 'Jun 30, 2016', 'AS Roma', 'Chelsea', '23,00 mil. €', 'End of loan']
# ['15/16', 'Aug 6, 2015', 'Chelsea', 'AS Roma', '18,00 mil. €', 'Loan fee:5,00 mil. €']
# ['14/15', 'Jun 30, 2015', 'Fiorentina', 'Chelsea', '12,00 mil. €', 'End of loan']
# ['14/15', 'Feb 2, 2015', 'Chelsea', 'Fiorentina', '13,00 mil. €', 'Loan']
# ['13/14', 'Jan 26, 2014', 'FC Basel', 'Chelsea', '8,50 mil. €', '16,50 mil. €']
# ['12/13', 'Jul 1, 2012', 'Arab Contr.', 'FC Basel', '1,50 mil. €', '2,50 mil. €']
# ['09/10', 'May 1, 2010', 'Arab Contr. U19', 'Arab Contr.', 0, 0]
# 	Mohamed Salah done
# ['18/19', 'Jul 13, 2018', 'Stoke City', 'Liverpool', '18,00 mil. €', '14,70 mil. €']
# ['15/16', 'Aug 11, 2015', 'Inter', 'Stoke City', '17,00 mil. €', '17,00 mil. €']
# ['15/16', 'Jul 1, 2015', 'Bayern Munich', 'Inter', '17,00 mil. €', '15,00 mil. €']
# ['14/15', 'Jun 30, 2015', 'Inter', 'Bayern Munich', '18,00 mil. €', 'End of loan']
# ['14/15', 'Jan 9, 2015', 'Bayern Munich', 'Inter', '20,00 mil. €', 'Loan']
# ['12/13', 'Jul 1, 2012', 'FC Basel', 'Bayern Munich', '12,50 mil. €', '11,80 mil. €']
# ['09/10', 'Jul 1, 2009', 'FC Basel U21', 'FC Basel', '50 thousand €', 0]
# ['08/09', 'Jul 1, 2008', 'FC Basel U18', 'FC Basel U21', 0, 0]
# ['07/08', 'Jul 1, 2007', 'FC Basel U16', 'FC Basel U18', 0, 0]
# 	Xherdan Shaqiri done
# ['15/16', 'Jul 1, 2015', 'TSG Hoffenheim', 'Liverpool', '25,00 mil. €', '41,00 mil. €']
# ['10/11', 'Jan 1, 2011', 'Tombense', 'TSG Hoffenheim', 0, '4,00 mil. €']
# ['10/11', 'Dec 31, 2010', 'Figueirense FC', 'Tombense', 0, 'End of loan']
# ['09/10', 'Apr 1, 2010', 'Tombense', 'Figueirense FC', 0, 'Loan']
# ['09/10', 'Mar 31, 2010', 'Figueirense FC', 'Tombense', 0, '?']
# ['09/10', 'Jan 1, 2010', 'Figueirense U17', 'Figueirense FC', 0, 0]
# 	Roberto Firmino done
# ['17/18', 'Jun 30, 2018', 'VfL Wolfsburg', 'Liverpool', '10,00 mil. €', 'End of loan']
# ['17/18', 'Aug 31, 2017', 'Liverpool', 'VfL Wolfsburg', '12,00 mil. €', 'Loan fee:6,50 mil. €']
# ['14/15', 'Jun 30, 2015', 'LOSC Lille', 'Liverpool', '9,00 mil. €', 'End of loan']
# ['14/15', 'Jul 30, 2014', 'Liverpool', 'LOSC Lille', '1,00 mil. €', 'Loan']
# ['14/15', 'Jul 29, 2014', 'LOSC Lille', 'Liverpool', '1,00 mil. €', '12,63 mil. €']
# ['13/14', 'Jul 1, 2013', 'LOSC Lille B', 'LOSC Lille', 0, 0]
# ['12/13', 'Jul 1, 2012', 'LOSC Lille U19', 'LOSC Lille B', 0, 0]
# ['11/12', 'Jul 1, 2011', 'LOSC Lille Yth.', 'LOSC Lille U19', 0, 0]
# ['10/11', 'Jul 1, 2010', 'KRC Genk Youth', 'LOSC Lille Yth.', 0, '?']
# 	Divock Origi done
# ['12/13', 'Aug 31, 2012', 'Olympique Lyon', 'Spurs', '19,00 mil. €', '12,60 mil. €']
# ['08/09', 'Jul 1, 2008', 'OGC Nice', 'Olympique Lyon', '8,50 mil. €', '8,50 mil. €']
# ['05/06', 'Jul 1, 2005', 'OGC Nice B', 'OGC Nice', '250 thousand €', 0]
# ['04/05', 'Jul 1, 2004', 'Nizza U19', 'OGC Nice B', 0, 0]
# 	Hugo Lloris done
# ['17/18', 'Aug 23, 2017', 'Southampton', 'Spurs', '1,00 mil. €', '?']
# ['16/17', 'Jun 30, 2017', 'Rayo Vallecano', 'Southampton', '1,00 mil. €', 'End of loan']
# ['16/17', 'Jul 29, 2016', 'Southampton', 'Rayo Vallecano', '1,00 mil. €', 'Loan']
# ['12/13', 'Jul 20, 2012', 'Gillingham FC', 'Southampton', 0, '3,15 mil. €']
# ['11/12', 'Jul 28, 2011', 'Valencia U19', 'Gillingham FC', 0, 'Available for free transfer']
# ['09/10', 'Jul 1, 2009', 'Valencia CF You', 'Valencia U19', 0, 0]
# 	Paulo Gazzaniga done
# ['17/18', 'Aug 23, 2017', 'Ajax', 'Spurs', '25,00 mil. â‚¬', '40,00 mil. â‚¬']
# ['16/17', 'Jul 28, 2016', 'Atl. Nacional', 'Ajax', '550 thousand â‚¬', '5,00 mil. â‚¬']
# ['14/15', 'Jul 1, 2014', 'Nacional U20', 'Atl. Nacional', 0, 0]
# ['13/14', 'Jul 1, 2013', 'CD AmÃ©rica U20', 'Nacional U20', 0, '?']
# 	Davinson SÃ¡nchez done
# ['15/16', 'Jul 8, 2015', 'Atlético Madrid', 'Spurs', '15,00 mil. €', '16,00 mil. €']
# ['14/15', 'Jun 30, 2015', 'Southampton', 'Atlético Madrid', '11,00 mil. €', 'End of loan']
# ['14/15', 'Sep 1, 2014', 'Atlético Madrid', 'Southampton', '10,00 mil. €', 'Loan']
# ['13/14', 'Sep 2, 2013', 'Ajax', 'Atlético Madrid', '10,00 mil. €', '7,00 mil. €']
# ['08/09', 'Jan 1, 2009', 'Ajax U21', 'Ajax', '50 thousand €', 0]
# ['08/09', 'Jul 1, 2008', 'Ajax U19', 'Ajax U21', 0, 0]
# ['06/07', 'Jul 1, 2006', 'Ajax U17', 'Ajax U19', 0, 0]
# ['05/06', 'Jul 1, 2005', 'Ajax Amsterdam', 'Ajax U17', 0, 0]
# ['04/05', 'Jul 1, 2004', 'GBA Youth', 'Ajax Amsterdam', 0, 'Available for free transfer']
# 	Toby Alderweireld done
# ['12/13', 'Jul 12, 2012', 'Ajax', 'Spurs', '15,00 mil. €', '12,50 mil. €']
# ['06/07', 'Jun 30, 2007', 'RKC Waalwijk', 'Ajax', '700 thousand €', 'End of loan']
# ['06/07', 'Jan 31, 2007', 'Ajax', 'RKC Waalwijk', '350 thousand €', 'Loan']
# ['06/07', 'Jul 1, 2006', 'Ajax U21', 'Ajax', 0, 0]
# ['05/06', 'Jul 1, 2005', 'Ajax U19', 'Ajax U21', 0, 0]
# ['04/05', 'Jul 1, 2004', 'Ajax U17', 'Ajax U19', 0, 0]
# ['03/04', 'Jul 1, 2003', 'GBA Youth', 'Ajax U17', 0, 'Available for free transfer']
# 	Jan Vertonghen done
# ['17/18', 'Aug 30, 2017', 'Estudiantes', 'Spurs', '5,00 mil. €', '13,00 mil. €']
# ['16/17', 'Jan 1, 2017', 'Estudiantes II', 'Estudiantes', 0, 0]
# 	Juan Foyth done
# ['12/13', 'May 31, 2013', 'Sunderland', 'Spurs', '5,00 mil. €', 'End of loan']
# ['12/13', 'Aug 31, 2012', 'Spurs', 'Sunderland', '3,00 mil. €', 'Loan']
# ['10/11', 'Feb 22, 2011', 'Bristol City', 'Spurs', '500 thousand €', 'End of loan']
# ['10/11', 'Sep 9, 2010', 'Spurs', 'Bristol City', '500 thousand €', 'Loan']
# ['09/10', 'Nov 11, 2009', 'Peterborough', 'Spurs', '500 thousand €', 'End of loan']
# ['09/10', 'Sep 29, 2009', 'Spurs', 'Peterborough', '500 thousand €', 'Loan']
# ['08/09', 'May 31, 2009', 'Watford', 'Spurs', '500 thousand €', 'End of loan']
# ['08/09', 'Mar 24, 2009', 'Spurs', 'Watford', '500 thousand €', 'Loan']
# ['07/08', 'Jul 25, 2007', 'Leeds U18', 'Spurs', 0, '1,00 mil. €']
# 	Danny Rose done
# ['14/15', 'Jul 23, 2014', 'Swansea', 'Spurs', '5,50 mil. €', '12,65 mil. €']
# ['12/13', 'Jul 1, 2012', 'Swansea U21', 'Swansea', 0, 0]
# ['11/12', 'Jul 1, 2011', 'Swansea U18', 'Swansea U21', 0, 0]
# ['09/10', 'Jul 1, 2009', 'Swansea Yth.', 'Swansea U18', 0, 0]
# ['05/06', 'Jul 1, 2005', 'Viborg FF Youth', 'Swansea Yth.', 0, 'Available for free transfer']
# ['02/03', 'Jul 1, 2002', 'Swansea Yth.', 'Viborg FF Youth', 0, 'Available for free transfer']
# 	Ben Davies done
# ['17/18', 'Aug 31, 2017', 'Paris SG', 'Spurs', '15,00 mil. €', '25,00 mil. €']
# ['15/16', 'Jul 1, 2015', 'Toulouse', 'Paris SG', '10,00 mil. €', '10,00 mil. €']
# ['14/15', 'Jun 30, 2015', 'Paris SG', 'Toulouse', '10,00 mil. €', 'End of loan']
# ['14/15', 'Jul 23, 2014', 'Toulouse', 'Paris SG', '6,50 mil. €', 'Loan']
# ['11/12', 'Jan 26, 2012', 'Lens', 'Toulouse', '2,00 mil. €', '1,30 mil. €']
# ['10/11', 'Jul 1, 2010', 'RC Lens B', 'Lens', 0, 0]
# ['09/10', 'Dec 1, 2009', 'RC Lens U19', 'RC Lens B', 0, 0]
# 	Serge Aurier done
# ['17/18', 'Jul 1, 2017', 'Tottenham U23', 'Spurs', '250 thousand €', 0]
# ['14/15', 'Jul 1, 2014', 'Tottenham U18', 'Tottenham U21', 0, 0]
# 	Kyle Walker-Peters done
# ['14/15', 'Jul 31, 2014', 'Sporting CP', 'Spurs', '3,50 mil. €', '5,00 mil. €']
# ['12/13', 'Jul 1, 2012', 'Sporting U19', 'Sporting CP', 0, 0]
# ['11/12', 'Jun 30, 2012', 'Everton U18', 'Sporting U19', 0, 'End of loan']
# ['10/11', 'Jan 20, 2011', 'Sporting U19', 'Everton U18', 0, 'Loan']
# ['10/11', 'Jul 1, 2010', 'Sporting Sub17', 'Sporting U19', 0, 0]
# ['09/10', 'Jul 1, 2009', 'Sporting Sub-15', 'Sporting Sub17', 0, 0]
# 	Eric Dier done
# ['16/17', 'Jul 1, 2016', 'Southampton', 'Spurs', '15,00 mil. €', '14,40 mil. €']
# ['13/14', 'Jul 11, 2013', 'Celtic', 'Southampton', '5,00 mil. €', '14,50 mil. €']
# ['11/12', 'Jul 4, 2011', 'Beerschot AC', 'Celtic', '1,20 mil. €', '1,10 mil. €']
# ['08/09', 'Jul 1, 2008', 'Helsingborg U21', 'Germ. Beerschot', 0, 'Available for free transfer']
# ['07/08', 'Jul 1, 2007', 'AFC Leopards', 'Helsingborg U21', 0, 'Available for free transfer']
# ['06/07', 'Jul 1, 2006', 'Nairobi City Stars', 'AFC Leopards', 0, 'Available for free transfer']
# 	Victor Wanyama done
# ['18/19', 'Jul 1, 2018', 'Tottenham U23', 'Spurs', 0, 0]
# ['17/18', 'Jul 1, 2017', 'Tottenham U18', 'Tottenham U23', 0, 0]
# ['16/17', 'Jul 1, 2016', 'Tottenham Yth.', 'Tottenham U18', 0, 0]
# 	Oliver Skipp done
# ['19/20', 'Jul 2, 2019', 'Olympique Lyon', 'Spurs', '65,00 mil. €', '60,00 mil. €']
# ['18/19', 'Jul 1, 2018', 'SC Amiens', 'Olympique Lyon', '25,00 mil. €', '8,00 mil. €']
# ['17/18', 'Jun 30, 2018', 'Olympique Lyon', 'SC Amiens', '25,00 mil. €', 'End of loan']
# ['17/18', 'Aug 31, 2017', 'SC Amiens', 'Olympique Lyon', '1,00 mil. €', 'Loan fee:2,00 mil. €']
# ['16/17', 'Jul 1, 2016', 'SC Amiens B', 'SC Amiens', 0, 0]
# ['14/15', 'Jul 1, 2014', 'EA Guingamp U19', 'SC Amiens B', 0, 'Available for free transfer']
# 	Tanguy Ndombélé done
# ['19/20', 'Aug 8, 2019', 'Real Betis', 'Spurs', '50,00 mil. €', 'Loan fee:16,00 mil. €']
# ['19/20', 'Jul 1, 2019', 'Paris SG', 'Real Betis', '50,00 mil. €', '22,00 mil. €']
# ['18/19', 'Jun 30, 2019', 'Real Betis', 'Paris SG', '50,00 mil. €', 'End of loan']
# ['18/19', 'Aug 31, 2018', 'Paris SG', 'Real Betis', '30,00 mil. €', 'Loan fee:3,00 mil. €']
# ['16/17', 'Dec 31, 2016', 'CA Rosario', 'Paris SG', '10,00 mil. €', 'End of loan']
# ['16/17', 'Jul 27, 2016', 'Paris SG', 'CA Rosario', '7,50 mil. €', 'Loan']
# ['16/17', 'Jul 26, 2016', 'CA Rosario', 'Paris SG', '7,50 mil. €', '10,00 mil. €']
# ['15/16', 'Jul 1, 2015', 'CA Rosario U19', 'CA Rosario', 0, 0]
# 	Giovani Lo Celso done
# ['16/17', 'Jul 1, 2016', 'Tottenham U23', 'Spurs', 0, 0]
# ['14/15', 'Jul 1, 2014', 'Tottenham U18', 'Tottenham U21', 0, 0]
# 	Harry Winks done
# ['16/17', 'Aug 31, 2016', 'Newcastle', 'Spurs', '13,00 mil. €', '35,00 mil. €']
# ['12/13', 'Jan 21, 2013', 'Toulouse', 'Newcastle', '10,00 mil. €', '2,00 mil. €']
# ['07/08', 'Jul 1, 2007', 'Toulouse B', 'Toulouse', '150 thousand €', 0]
# ['06/07', 'Jul 1, 2006', 'FC Toulouse U19', 'Toulouse B', 0, 0]
# 	Moussa Sissoko done
# ['19/20', 'Aug 8, 2019', 'Fulham', 'Spurs', '35,00 mil. €', '27,00 mil. €']
# ['16/17', 'Jul 1, 2016', 'Fulham U18', 'Fulham', 0, 0]
# ['15/16', 'Jul 1, 2015', 'Fulham Youth', 'Fulham U18', 0, 0]
# 	Ryan Sessegnon done
# ['13/14', 'Aug 30, 2013', 'Ajax', 'Spurs', '18,00 mil. €', '13,50 mil. €']
# ['09/10', 'Jan 1, 2010', 'Ajax U19', 'Ajax', 0, 0]
# ['08/09', 'Jan 1, 2009', 'Odense BK Youth', 'Ajax U19', 0, '1,50 mil. €']
# 	Christian Eriksen done
# ['14/15', 'May 31, 2015', 'MK Dons', 'Spurs', '5,00 mil. €', 'End of loan']
# ['14/15', 'Feb 3, 2015', 'Spurs', 'MK Dons', '2,00 mil. €', 'Loan']
# ['14/15', 'Feb 2, 2015', 'MK Dons', 'Spurs', '2,00 mil. €', '6,63 mil. €']
# ['13/14', 'Jul 1, 2013', 'MK Dons U18', 'MK Dons', 0, 0]
# 	Dele Alli done
# ['15/16', 'Aug 28, 2015', 'Bay. Leverkusen', 'Spurs', '16,00 mil. €', '30,00 mil. €']
# ['13/14', 'Jul 1, 2013', 'Hamburger SV', 'Bay. Leverkusen', '14,00 mil. €', '10,00 mil. €']
# ['10/11', 'Jul 1, 2010', 'Hamburg U19', 'Hamburger SV', 0, 0]
# ['09/10', 'Dec 31, 2009', 'FC Seoul Yth.', 'Hamburg U19', 0, 'End of loan']
# ['09/10', 'Jul 2, 2009', 'Hamburg U19', 'FC Seoul Yth.', 0, 'Loan']
# ['09/10', 'Jul 1, 2009', 'Hamburg U17', 'Hamburg U19', 0, 0]
# ['08/09', 'Aug 1, 2008', 'FC Seoul Yth.', 'Hamburg U17', 0, 'Available for free transfer']
# 	Heung-min Son done
# ['17/18', 'Jan 31, 2018', 'Paris SG', 'Spurs', '28,00 mil. €', '28,40 mil. €']
# ['12/13', 'Jan 1, 2013', 'São Paulo', 'Paris SG', '35,00 mil. €', '40,00 mil. €']
# ['10/11', 'Aug 1, 2010', 'FC São Paulo B', 'São Paulo', 0, 0]
# ['08/09', 'Jan 1, 2009', 'São Paulo U17', 'FC São Paulo B', 0, 0]
# 	Lucas Moura done
# ['13/14', 'Aug 30, 2013', 'AS Roma', 'Spurs', '23,00 mil. €', '30,00 mil. €']
# ['11/12', 'Aug 6, 2011', 'River Plate', 'AS Roma', '5,00 mil. €', '17,00 mil. €']
# ['10/11', 'Jul 1, 2010', 'River Plate II', 'River Plate', '100 thousand €', 0]
# ['08/09', 'Jan 1, 2009', 'River Plate U20', 'River Plate II', 0, 0]
# 	Erik Lamela done
# ['12/13', 'May 14, 2013', 'Leicester', 'Spurs', '500 thousand €', 'End of loan']
# ['12/13', 'Feb 21, 2013', 'Spurs', 'Leicester', '500 thousand €', 'Loan']
# ['12/13', 'Feb 1, 2013', 'Norwich', 'Spurs', '500 thousand €', 'End of loan']
# ['12/13', 'Aug 31, 2012', 'Spurs', 'Norwich', 0, 'Loan']
# ['11/12', 'May 31, 2012', 'Millwall', 'Spurs', 0, 'End of loan']
# ['11/12', 'Jan 1, 2012', 'Spurs', 'Millwall', 0, 'Loan']
# ['10/11', 'May 31, 2011', 'Leyton Orient', 'Spurs', 0, 'End of loan']
# ['10/11', 'Jan 7, 2011', 'Spurs', 'Leyton Orient', 0, 'Loan']
# ['10/11', 'Jan 1, 2011', 'Tottenham U18', 'Spurs', 0, 0]
# ['09/10', 'Jul 1, 2009', 'Tottenham Yth.', 'Tottenham U18', 0, 0]
# 	Harry Kane done
# ['18/19', 'Aug 8, 2018', 'Athletic', 'Chelsea', '20,00 mil. €', '80,00 mil. €']
# ['15/16', 'Jun 30, 2016', 'Real Valladolid', 'Athletic', '1,50 mil. €', 'End of loan']
# ['15/16', 'Jul 20, 2015', 'Athletic', 'Real Valladolid', '1,00 mil. €', 'Loan']
# ['14/15', 'Jun 30, 2015', 'Ponferradina', 'Athletic', '1,00 mil. €', 'End of loan']
# ['14/15', 'Jan 5, 2015', 'Athletic', 'Ponferradina', '1,00 mil. €', 'Loan']
# ['14/15', 'Jul 1, 2014', 'Bilbao Athletic', 'Athletic', '500 thousand €', 0]
# ['12/13', 'Jan 31, 2013', 'CD Basconia', 'Bilbao Athletic', '500 thousand €', 0]
# ['11/12', 'Jan 1, 2012', 'Bilbao U19', 'CD Basconia', 0, 0]
# 	Kepa done
# ['17/18', 'Jul 1, 2017', 'Man City', 'Chelsea', '1,50 mil. €', 'Available for free transfer']
# ['14/15', 'Jul 8, 2014', 'Málaga CF', 'Man City', '5,00 mil. €', '8,00 mil. €']
# ['10/11', 'Feb 11, 2011', 'Elche CF', 'Málaga CF', '1,60 mil. €', '900 thousand €']
# ['05/06', 'Jun 30, 2006', 'Arsenal FC', 'Elche CF', '1,25 mil. €', 'End of loan']
# ['05/06', 'Dec 28, 2005', 'Elche CF', 'Arsenal FC', '1,25 mil. €', 'Loan']
# ['04/05', 'Aug 7, 2004', 'Boca Juniors', 'Elche CF', 0, '700 thousand €']
# ['00/01', 'Jul 1, 2000', 'Boca U20', 'Boca Juniors', 0, 0]
# 	Willy Caballero done
# ['17/18', 'Jul 9, 2017', 'AS Roma', 'Chelsea', '25,00 mil. €', '35,00 mil. €']
# ['16/17', 'Jul 1, 2016', 'VfB Stuttgart', 'AS Roma', '12,00 mil. €', '9,00 mil. €']
# ['15/16', 'Jun 30, 2016', 'AS Roma', 'VfB Stuttgart', '12,00 mil. €', 'End of loan']
# ['15/16', 'Aug 19, 2015', 'VfB Stuttgart', 'AS Roma', '10,00 mil. €', 'Loan fee:4,00 mil. €']
# ['12/13', 'Jul 1, 2012', 'Stuttgart II', 'VfB Stuttgart', '500 thousand €', 0]
# ['11/12', 'Jul 1, 2011', 'Stuttgart U19', 'Stuttgart II', 0, 0]
# ['10/11', 'Feb 1, 2011', 'B. Dortmund U19', 'Stuttgart U19', 0, 'Available for free transfer']
# ['10/11', 'Jul 1, 2010', 'B. Dortmund U17', 'B. Dortmund U19', 0, 0]
# ['08/09', 'Jul 1, 2008', 'Zehlendorf Yth.', 'B. Dortmund U17', 0, 'Available for free transfer']
# ['06/07', 'Jul 1, 2006', 'Neuk. SF Yth.', 'Zehlendorf Yth.', 0, 'Available for free transfer']
# ['05/06', 'Jul 1, 2005', 'Tasmania Yth.', 'Neuk. SF Yth.', 0, 'Available for free transfer']
# ['02/03', 'Jul 1, 2002', 'Neukölln Yth.', 'Tasmania Yth.', 0, 'Available for free transfer']
# 	Antonio Rüdiger done
# ['16/17', 'Jun 30, 2017', "Bor. M'gladbach", 'Chelsea', '18,00 mil. €', 'End of loan']
# ['15/16', 'Jul 10, 2015', 'Chelsea', "Bor. M'gladbach", '1,50 mil. €', 'Loan']
# ['15/16', 'Jul 1, 2015', 'Chelsea U21', 'Chelsea', '1,50 mil. €', 0]
# ['13/14', 'Jul 1, 2013', 'Chelsea U18', 'Chelsea U21', 0, 0]
# ['12/13', 'Jul 1, 2012', 'Bröndby IF U17', 'Chelsea U18', 0, 'Available for free transfer']
# ['11/12', 'Jul 1, 2011', 'Bröndby Youth', 'Bröndby IF U17', 0, 0]
# 	Andreas Christensen done
# ['18/19', 'May 31, 2019', 'Everton', 'Chelsea', '20,00 mil. €', 'End of loan']
# ['18/19', 'Aug 9, 2018', 'Chelsea', 'Everton', '15,00 mil. €', 'Loan fee:7,90 mil. €']
# ['17/18', 'May 31, 2018', 'Stoke City', 'Chelsea', '15,00 mil. €', 'End of loan']
# ['17/18', 'Jul 21, 2017', 'Chelsea', 'Stoke City', '15,00 mil. €', 'Loan fee:7,80 mil. €']
# ['13/14', 'Jun 30, 2014', 'Saint-Étienne', 'Chelsea', '10,00 mil. €', 'End of loan']
# ['13/14', 'Feb 1, 2014', 'Chelsea', 'Saint-Étienne', '7,50 mil. €', 'Loan']
# ['13/14', 'Jan 31, 2014', 'Saint-Étienne', 'Chelsea', '7,50 mil. €', '14,60 mil. €']
# ['11/12', 'Jul 1, 2011', 'St-Étienne U19', 'Saint-Étienne', 0, 0]
# 	Kurt Zouma done
# ['19/20', 'Jul 1, 2019', 'Chelsea U23', 'Chelsea', '7,00 mil. €', 0]
# ['18/19', 'May 31, 2019', 'Derby', 'Chelsea U23', '7,00 mil. €', 'End of loan']
# ['18/19', 'Aug 6, 2018', 'Chelsea U23', 'Derby', '1,00 mil. €', 'Loan']
# ['17/18', 'May 31, 2018', 'Hull City', 'Chelsea U23', '1,00 mil. €', 'End of loan']
# ['17/18', 'Aug 31, 2017', 'Chelsea U23', 'Hull City', '250 thousand €', 'Loan']
# ['16/17', 'May 31, 2017', 'Brighton', 'Chelsea U23', '250 thousand €', 'End of loan']
# ['16/17', 'Jan 23, 2017', 'Chelsea U23', 'Brighton', 0, 'Loan']
# ['15/16', 'Jul 1, 2015', 'Chelsea U18', 'Chelsea U21', 0, 0]
# ['14/15', 'Jul 1, 2014', 'Chelsea Youth', 'Chelsea U18', 0, 0]
# 	Fikayo Tomori done
# ['18/19', 'May 31, 2019', 'Sheff Wed', 'Chelsea', '3,00 mil. €', 'End of loan']
# ['18/19', 'Aug 31, 2018', 'Chelsea', 'Sheff Wed', '3,00 mil. €', 'Loan']
# ['17/18', 'May 31, 2018', 'Hull City', 'Chelsea', '3,00 mil. €', 'End of loan']
# ['17/18', 'Jul 27, 2017', 'Chelsea', 'Hull City', '3,00 mil. €', 'Loan']
# ['16/17', 'Jun 30, 2017', 'E. Frankfurt', 'Chelsea', '3,00 mil. €', 'End of loan']
# ['16/17', 'Aug 14, 2016', 'Chelsea', 'E. Frankfurt', '4,00 mil. €', 'Loan']
# ['15/16', 'Apr 28, 2016', 'Reading', 'Chelsea', '3,00 mil. €', 'End of loan']
# ['15/16', 'Sep 2, 2015', 'Chelsea', 'Reading', '750 thousand €', 'Loan']
# ['15/16', 'Sep 1, 2015', 'Reading', 'Chelsea', '750 thousand €', '5,40 mil. €']
# ['13/14', 'Jan 7, 2014', 'Aberdeen FC', 'Reading', '75 thousand €', 'End of loan']
# ['13/14', 'Jul 26, 2013', 'Reading', 'Aberdeen FC', 0, 'Loan']
# ['12/13', 'May 31, 2013', 'Cheltenham Town', 'Reading', 0, 'End of loan']
# ['12/13', 'Jan 30, 2013', 'Reading', 'Cheltenham Town', 0, 'Loan']
# ['12/13', 'Jan 29, 2013', 'Aldershot Town', 'Reading', 0, 'End of loan']
# ['12/13', 'Nov 22, 2012', 'Reading', 'Aldershot Town', 0, 'Loan']
# ['12/13', 'Nov 18, 2012', 'Shrewsbury', 'Reading', 0, 'End of loan']
# ['12/13', 'Jul 24, 2012', 'Reading', 'Shrewsbury', 0, 'Loan']
# ['11/12', 'May 6, 2012', 'Barnet', 'Reading', '50 thousand €', 'End of loan']
# ['11/12', 'Nov 3, 2011', 'Reading', 'Barnet', '50 thousand €', 'Loan']
# ['10/11', 'May 30, 2011', 'Dundalk FC', 'Reading', 0, 'End of loan']
# ['10/11', 'Feb 2, 2011', 'Reading', 'Dundalk FC', 0, 'Loan']
# ['10/11', 'Jan 7, 2011', 'Horsham FC', 'Reading', 0, 'End of loan']
# ['10/11', 'Nov 7, 2010', 'Reading', 'Horsham FC', 0, 'Loan']
# ['10/11', 'Jul 1, 2010', 'Reading U18', 'Reading', 0, 0]
# ['09/10', 'May 31, 2010', 'Bracknell', 'Reading U18', 0, 'End of loan']
# ['09/10', 'Jan 5, 2010', 'Reading U18', 'Bracknell', 0, 'Loan']
# ['09/10', 'Dec 5, 2009', 'Havant & Water.', 'Reading U18', 0, 'End of loan']
# ['09/10', 'Aug 5, 2009', 'Reading U18', 'Havant & Water.', 0, 'Loan']
# 	Michael Hector done
# ['16/17', 'Aug 31, 2016', 'Fiorentina', 'Chelsea', '9,00 mil. €', '23,00 mil. €']
# ['13/14', 'Jun 30, 2014', 'Sunderland', 'Fiorentina', '2,00 mil. €', 'End of loan']
# ['13/14', 'Jan 1, 2014', 'Fiorentina', 'Sunderland', '2,00 mil. €', 'Loan']
# ['13/14', 'Jul 1, 2013', 'Bolton', 'Fiorentina', '1,50 mil. €', 'Available for free transfer']
# ['10/11', 'Jul 1, 2010', 'RM Castilla', 'Bolton', 0, '2,40 mil. €']
# ['08/09', 'Jul 1, 2008', 'Real Madrid U19', 'RM Castilla', 0, 0]
# 	Marcos Alonso done
# ['17/18', 'Jan 30, 2018', 'AS Roma', 'Chelsea', '14,00 mil. €', '20,00 mil. €']
# ['16/17', 'Jan 3, 2017', 'Santos FC', 'AS Roma', '3,00 mil. €', '2,00 mil. €']
# ['16/17', 'Jan 2, 2017', 'AS Roma', 'Santos FC', '3,00 mil. €', 'End of loan']
# ['15/16', 'Aug 26, 2015', 'Santos FC', 'AS Roma', '400 thousand €', 'Loan']
# ['14/15', 'Jun 30, 2015', 'US Palermo', 'Santos FC', '400 thousand €', 'End of loan']
# ['14/15', 'Aug 25, 2014', 'Santos FC', 'US Palermo', '500 thousand €', 'Loan']
# ['12/13', 'Jan 1, 2013', 'Santos B', 'Santos FC', '150 thousand €', 0]
# ['11/12', 'Jan 1, 2012', 'Santos FC U20', 'Santos B', 0, 0]
# 	Emerson done
# ['12/13', 'Aug 24, 2012', 'Marseille', 'Chelsea', '7,50 mil. €', '8,80 mil. €']
# ['10/11', 'Jul 1, 2010', 'CA Osasuna', 'Marseille', '7,00 mil. €', '6,00 mil. €']
# ['07/08', 'Jul 1, 2007', 'CA Osasuna Prom', 'CA Osasuna', 0, 0]
# ['06/07', 'Jul 1, 2006', 'CA Osasuna Yout', 'CA Osasuna Prom', 0, 0]
# 	César Azpilicueta done
# ['19/20', 'Jul 1, 2019', 'Chelsea U23', 'Chelsea', '7,00 mil. €', 0]
# ['18/19', 'May 31, 2019', 'Wigan', 'Chelsea U23', '1,00 mil. €', 'End of loan']
# ['18/19', 'Jul 1, 2018', 'Chelsea U23', 'Wigan', 0, 'Loan']
# ['17/18', 'Jul 1, 2017', 'Chelsea U18', 'Chelsea U23', 0, 0]
# ['16/17', 'Jul 1, 2016', 'Chelsea Youth', 'Chelsea U18', 0, 0]
# 	Reece James done
# ['18/19', 'Jul 14, 2018', 'SSC Napoli', 'Chelsea', '50,00 mil. €', '57,00 mil. €']
# ['13/14', 'Jan 18, 2014', 'Hellas Verona', 'SSC Napoli', '10,00 mil. €', '9,50 mil. €']
# ['10/11', 'Jun 30, 2011', 'Sambonifacese', 'Hellas Verona', 0, 'End of loan']
# ['10/11', 'Jul 2, 2010', 'Hellas Verona', 'Sambonifacese', 0, 'Loan']
# ['10/11', 'Jul 1, 2010', 'Verona U19', 'Hellas Verona', 0, 0]
# 	Jorginho done
# ['16/17', 'Jul 16, 2016', 'Leicester', 'Chelsea', '20,00 mil. €', '35,80 mil. €']
# ['15/16', 'Aug 3, 2015', 'SM Caen', 'Leicester', '4,50 mil. €', '9,00 mil. €']
# ['13/14', 'Jul 1, 2013', 'US Boulogne', 'SM Caen', '50 thousand €', 'Available for free transfer']
# ['12/13', 'Jul 1, 2012', 'Boulogne B', 'US Boulogne', 0, 0]
# 	N'Golo Kanté done
# ['19/20', 'Jul 1, 2019', 'Real Madrid', 'Chelsea', '35,00 mil. €', '45,00 mil. €']
# ['18/19', 'Jun 30, 2019', 'Chelsea', 'Real Madrid', '35,00 mil. €', 'End of loan']
# ['18/19', 'Aug 9, 2018', 'Real Madrid', 'Chelsea', '30,00 mil. €', 'Loan']
# ['15/16', 'Aug 18, 2015', 'Inter', 'Real Madrid', '22,00 mil. €', '38,00 mil. €']
# ['12/13', 'Jan 31, 2013', 'Dinamo Zagreb', 'Inter', '3,00 mil. €', '11,00 mil. €']
# ['10/11', 'Oct 1, 2010', 'Din. Zagreb U17', 'Dinamo Zagreb', 0, 0]
# ['09/10', 'Jul 1, 2009', 'D. Zagreb Yth.', 'Din. Zagreb U17', 0, 0]
# ['07/08', 'Mar 1, 2008', 'LASK Youth', 'D. Zagreb Yth.', 0, '?']
# ['00/01', 'Sep 1, 2000', 'Ebelsberg J.', 'LASK Youth', 0, '?']
# 	Mateo Kovacic done
# ['17/18', 'Jan 5, 2018', 'Everton', 'Chelsea', '25,00 mil. €', '16,80 mil. €']
# ['12/13', 'Feb 11, 2013', 'Leeds', 'Everton', '4,50 mil. €', 'End of loan']
# ['12/13', 'Jan 11, 2013', 'Everton', 'Leeds', '4,50 mil. €', 'Loan']
# ['12/13', 'Nov 19, 2012', 'Sheff Wed', 'Everton', '4,50 mil. €', 'End of loan']
# ['12/13', 'Sep 14, 2012', 'Everton', 'Sheff Wed', '4,50 mil. €', 'Loan']
# ['11/12', 'Jul 1, 2011', 'Everton U18', 'Everton', 0, 0]
# ['09/10', 'Jul 1, 2009', 'Everton FC Yout', 'Everton U18', 0, 0]
# 	Ross Barkley done
# ['17/18', 'May 31, 2018', 'Crystal Palace', 'Chelsea', '15,00 mil. €', 'End of loan']
# ['17/18', 'Jul 12, 2017', 'Chelsea', 'Crystal Palace', '5,00 mil. €', 'Loan']
# ['14/15', 'Jan 1, 2015', 'Chelsea U21', 'Chelsea', '150 thousand €', 0]
# ['14/15', 'Jul 1, 2014', 'Chelsea U18', 'Chelsea U21', '150 thousand €', 0]
# ['12/13', 'Jul 1, 2012', 'Chelsea Youth', 'Chelsea U18', 0, 0]
# 	Ruben Loftus-Cheek done
# ['17/18', 'Jun 30, 2018', 'PSV Eindhoven', 'Chelsea', '12,00 mil. €', 'End of loan']
# ['16/17', 'Jan 1, 2017', 'Chelsea', 'PSV Eindhoven', '7,00 mil. €', 'Loan']
# ['15/16', 'Jun 30, 2016', 'PSV Eindhoven', 'Chelsea', '7,00 mil. €', 'End of loan']
# ['15/16', 'Feb 1, 2016', 'Chelsea', 'PSV Eindhoven', '7,50 mil. €', 'Loan']
# ['15/16', 'Jan 31, 2016', 'Stoke City', 'Chelsea', '7,50 mil. €', 'End of loan']
# ['15/16', 'Jul 10, 2015', 'Chelsea', 'Stoke City', '7,50 mil. €', 'Loan']
# ['14/15', 'Jun 30, 2015', 'AC Milan', 'Chelsea', '7,50 mil. €', 'End of loan']
# ['14/15', 'Aug 31, 2014', 'Chelsea', 'AC Milan', '9,00 mil. €', 'Loan fee:1,00 mil. €']
# ['13/14', 'Jul 4, 2013', 'Vitesse', 'Chelsea', '8,00 mil. €', '9,40 mil. €']
# ['10/11', 'Jul 1, 2010', 'Vit./AGOVV U19', 'Vitesse', 0, 0]
# ['09/10', 'Jul 1, 2009', 'VIT/AGOVV U17', 'Vit./AGOVV U19', 0, 0]
# 	Marco van Ginkel done
# ['19/20', 'Jul 1, 2019', 'Chelsea U23', 'Chelsea', '12,00 mil. €', 0]
# ['18/19', 'May 31, 2019', 'Derby', 'Chelsea U23', '10,00 mil. €', 'End of loan']
# ['18/19', 'Jul 17, 2018', 'Chelsea U23', 'Derby', '4,00 mil. €', 'Loan']
# ['17/18', 'Jun 30, 2018', 'Vitesse', 'Chelsea U23', '4,00 mil. €', 'End of loan']
# ['17/18', 'Jul 24, 2017', 'Chelsea U23', 'Vitesse', '400 thousand €', 'Loan']
# ['16/17', 'Jul 1, 2016', 'Chelsea U18', 'Chelsea U23', 0, 0]
# ['15/16', 'Jul 1, 2015', 'Chelsea Youth', 'Chelsea U18', 0, 0]
# 	Mason Mount done
# ['18/19', 'Jan 1, 2019', 'Chelsea U23', 'Chelsea', 0, 0]
# ['17/18', 'Jul 1, 2017', 'Chelsea U18', 'Chelsea U23', 0, 0]
# ['16/17', 'Jul 1, 2016', 'Chelsea Youth', 'Chelsea U18', 0, 0]
# 	Callum Hudson-Odoi done
# ['18/19', 'Jun 30, 2019', 'Bor. Dortmund', 'Chelsea', '60,00 mil. €', 'End of loan']
# ['18/19', 'Jan 3, 2019', 'Chelsea', 'Bor. Dortmund', '50,00 mil. €', 'Loan']
# ['18/19', 'Jan 2, 2019', 'Bor. Dortmund', 'Chelsea', '50,00 mil. €', '64,00 mil. €']
# ['15/16', 'Jan 4, 2016', 'B. Dortmund U19', 'Bor. Dortmund', 0, 0]
# ['15/16', 'Jul 1, 2015', 'B. Dortmund U17', 'B. Dortmund U19', 0, 0]
# ['14/15', 'Feb 10, 2015', 'PA Classics', 'B. Dortmund U17', 0, 'Available for free transfer']
# 	Christian Pulisic done
# ['13/14', 'Aug 28, 2013', 'Anzhi', 'Chelsea', '30,00 mil. €', '35,50 mil. €']
# ['12/13', 'Jan 31, 2013', 'Shakhtar D.', 'Anzhi', '25,00 mil. €', '35,00 mil. €']
# ['07/08', 'Aug 24, 2007', 'Corinthians', 'Shakhtar D.', '11,00 mil. €', '14,00 mil. €']
# ['05/06', 'Jan 1, 2006', 'Corinthians U20', 'Corinthians', 0, 0]
# 	Willian done
# ['15/16', 'Aug 20, 2015', 'FC Barcelona', 'Chelsea', '20,00 mil. €', '27,00 mil. €']
# ['07/08', 'Jan 1, 2008', 'FC Barcelona B', 'FC Barcelona', 0, 0]
# ['06/07', 'Jul 1, 2006', 'Barça U19', 'FC Barcelona B', 0, 0]
# ['04/05', 'Jul 1, 2004', 'San Isidro', 'Barça U19', 0, 'Available for free transfer']
# 	Pedro done
# ['18/19', 'May 31, 2019', 'Aston Villa', 'Chelsea', '15,00 mil. €', 'End of loan']
# ['18/19', 'Aug 31, 2018', 'Chelsea', 'Aston Villa', '10,00 mil. €', 'Loan']
# ['17/18', 'May 31, 2018', 'Swansea', 'Chelsea', '10,00 mil. €', 'End of loan']
# ['17/18', 'Jul 4, 2017', 'Chelsea', 'Swansea', '8,00 mil. €', 'Loan']
# ['17/18', 'Jul 1, 2017', 'Chelsea U23', 'Chelsea', '8,00 mil. €', 0]
# ['16/17', 'May 31, 2017', 'Bristol City', 'Chelsea U23', '5,00 mil. €', 'End of loan']
# ['16/17', 'Aug 5, 2016', 'Chelsea U23', 'Bristol City', 0, 'Loan']
# ['15/16', 'Jul 1, 2015', 'Chelsea U18', 'Chelsea U21', 0, 0]
# ['14/15', 'Jul 1, 2014', 'Chelsea Youth', 'Chelsea U18', 0, 0]
# 	Tammy Abraham done
# ['18/19', 'Jun 30, 2019', 'Crystal Palace', 'Chelsea', '30,00 mil. €', 'End of loan']
# ['18/19', 'Jan 31, 2019', 'Chelsea', 'Crystal Palace', '30,00 mil. €', 'Loan fee:1,15 mil. €']
# ['18/19', 'Jan 30, 2019', 'Valencia', 'Chelsea', '30,00 mil. €', 'End of loan']
# ['18/19', 'Aug 10, 2018', 'Chelsea', 'Valencia', '40,00 mil. €', 'Loan fee:3,00 mil. €']
# ['17/18', 'Jun 30, 2018', 'Bor. Dortmund', 'Chelsea', '40,00 mil. €', 'End of loan']
# ['17/18', 'Jan 31, 2018', 'Chelsea', 'Bor. Dortmund', '25,00 mil. €', 'Loan fee:1,50 mil. €']
# ['16/17', 'Jul 3, 2016', 'Marseille', 'Chelsea', '15,00 mil. €', '39,00 mil. €']
# ['14/15', 'Jul 1, 2014', 'Standard Liège', 'Marseille', '8,00 mil. €', '6,00 mil. €']
# ['11/12', 'Jul 1, 2011', 'Standard Res.', 'Standard Liège', 0, 0]
# ['10/11', 'Jul 1, 2010', 'Standard U17', 'Standard Res.', 0, 0]
# 	Michy Batshuayi done
# ['17/18', 'Jan 31, 2018', 'Arsenal', 'Chelsea', '20,00 mil. €', '17,00 mil. €']
# ['12/13', 'Jul 1, 2012', 'Montpellier', 'Arsenal', '13,00 mil. €', '12,00 mil. €']
# ['10/11', 'Jul 1, 2010', 'Tours FC', 'Montpellier', '3,00 mil. €', '2,00 mil. €']
# ['08/09', 'Sep 1, 2008', 'Grenoble', 'Tours FC', '50 thousand €', '?']
# ['07/08', 'Jun 30, 2008', 'FC Istres', 'Grenoble', 0, 'End of loan']
# ['07/08', 'Jul 1, 2007', 'Grenoble', 'FC Istres', 0, 'Loan']
# ['05/06', 'Mar 22, 2006', 'Grenoble B', 'Grenoble', 0, 0]
# ['05/06', 'Jul 1, 2005', 'Grenoble U19', 'Grenoble B', 0, 0]
# 	Olivier Giroud done
# ['11/12', 'Jul 1, 2011', 'Atlético Madrid', 'Man Utd', '12,00 mil. €', '25,00 mil. €']
# ['09/10', 'Jul 1, 2009', 'Atl. Madrid B', 'Atlético Madrid', '100 thousand €', 0]
# ...
# 	George Baldock done
# ['15/16', 'May 31, 2016', 'Portsmouth', 'Sheffield Utd.', '350 thousand €', 'End of loan']
# ['15/16', 'Jan 28, 2016', 'Sheffield Utd.', 'Portsmouth', '350 thousand €', 'Loan']
# ['14/15', 'Jan 23, 2015', 'Derby', 'Sheffield Utd.', '400 thousand €', 'Available for free transfer']
# ['14/15', 'Jan 4, 2015', 'Mansfield Town', 'Derby', '400 thousand €', 'End of loan']
# ['14/15', 'Oct 3, 2014', 'Derby', 'Mansfield Town', '400 thousand €', 'Loan']
# ['13/14', 'May 31, 2014', 'Sheffield Utd.', 'Derby', '400 thousand €', 'End of loan']
# ['13/14', 'Mar 6, 2014', 'Derby', 'Sheffield Utd.', '400 thousand €', 'Loan']
# ['13/14', 'Mar 2, 2014', 'Notts County', 'Derby', '400 thousand €', 'End of loan']
# ['13/14', 'Jan 11, 2014', 'Derby', 'Notts County', '400 thousand €', 'Loan']
# ['13/14', 'Dec 24, 2013', 'Notts County', 'Derby', '400 thousand €', 'End of loan']
# ['13/14', 'Nov 12, 2013', 'Derby', 'Notts County', '400 thousand €', 'Loan']
# ['12/13', 'Aug 22, 2012', 'Nottm Forest', 'Derby', '75 thousand €', '?']
# ['11/12', 'May 1, 2012', 'Notts County', 'Nottm Forest', '75 thousand €', 'End of loan']
# ['11/12', 'Jan 1, 2012', 'Nottm Forest', 'Notts County', '50 thousand €', 'Loan']
# ['11/12', 'Dec 1, 2011', 'Mansfield Town', 'Nottm Forest', '50 thousand €', 'End of loan']
# ['11/12', 'Nov 1, 2011', 'Nottm Forest', 'Mansfield Town', '50 thousand €', 'Loan']
# ['11/12', 'Jul 1, 2011', 'Nottingham U18', 'Nottm Forest', 0, 0]
# 	Kieron Freeman done
# ['19/20', 'Aug 8, 2019', 'Everton', 'Sheffield Utd.', '5,00 mil. €', 'Loan']
# ['18/19', 'May 31, 2019', 'Middlesbrough', 'Everton', '5,00 mil. €', 'End of loan']
# ['18/19', 'Aug 23, 2018', 'Everton', 'Middlesbrough', '5,00 mil. €', 'Loan']
# ['17/18', 'May 31, 2018', 'Middlesbrough', 'Everton', '5,00 mil. €', 'End of loan']
# ['17/18', 'Jan 31, 2018', 'Everton', 'Middlesbrough', '5,00 mil. €', 'Loan']
# ['14/15', 'Jul 28, 2014', 'Ferencváros', 'Everton', '2,50 mil. €', '4,80 mil. €']
# ['12/13', 'Aug 31, 2012', 'Hamburger SV', 'Ferencváros', '500 thousand €', 'Available for free transfer']
# ['10/11', 'Jul 1, 2010', 'Hamburg U19', 'Hamburger SV', 0, 0]
# ['09/10', 'Jul 1, 2009', 'TeBe Berlin U17', 'Hamburg U19', 0, 'Available for free transfer']
# ['07/08', 'Jul 1, 2007', 'Füchse Yth.', 'TeBe Berlin U17', 0, '?']
# 	Muhamed Besic done
# ['16/17', 'Jul 8, 2016', 'Coventry', 'Sheffield Utd.', '400 thousand €', 'Available for free transfer']
# ['12/13', 'Jul 4, 2012', 'Rangers', 'Coventry', '500 thousand €', 'Available for free transfer']
# ['11/12', 'May 20, 2012', 'Blackpool', 'Rangers', '500 thousand €', 'End of loan']
# ['11/12', 'Jan 1, 2012', 'Rangers', 'Blackpool', '500 thousand €', 'Loan']
# ['08/09', 'Jan 1, 2009', 'Rangers U20', 'Rangers', '500 thousand €', 0]
# 	John Fleck done
# ['18/19', 'Jan 4, 2019', 'Brighton', 'Sheffield Utd.', '3,00 mil. €', '2,20 mil. €']
# ['18/19', 'Jan 3, 2019', 'Sheffield Utd.', 'Brighton', '3,00 mil. €', 'End of loan']
# ['18/19', 'Aug 13, 2018', 'Brighton', 'Sheffield Utd.', '3,00 mil. €', 'Loan']
# ['17/18', 'May 31, 2018', 'Fulham', 'Brighton', '3,00 mil. €', 'End of loan']
# ['17/18', 'Jul 25, 2017', 'Brighton', 'Fulham', '2,50 mil. €', 'Loan']
# ['16/17', 'Aug 3, 2016', 'Reading', 'Brighton', '2,00 mil. €', '?']
# ['14/15', 'Aug 21, 2014', 'Huddersfield', 'Reading', '1,00 mil. €', '1,50 mil. €']
# ['12/13', 'Jul 1, 2012', 'Man Utd U23', 'Huddersfield', 0, '505 thousand €']
# ['11/12', 'May 1, 2012', 'Coventry', 'Man Utd U23', 0, 'End of loan']
# ['11/12', 'Jan 1, 2012', 'Man Utd U23', 'Coventry', 0, 'Loan']
# ['11/12', 'Dec 1, 2011', 'Scunthorpe Utd.', 'Man Utd U23', 0, 'End of loan']
# ['11/12', 'Aug 1, 2011', 'Man Utd U23', 'Scunthorpe Utd.', 0, 'Loan']
# ['10/11', 'Nov 1, 2010', 'Carlisle United', 'Man Utd U23', 0, 'End of loan']
# ['10/11', 'Sep 1, 2010', 'Man Utd U23', 'Carlisle United', 0, 'Loan']
# ['09/10', 'Jul 1, 2009', 'Man Utd U18', 'Man Utd U23', 0, 0]
# 	Oliver Norwood done
# ['17/18', 'Jul 25, 2017', 'Oxford United', 'Sheffield Utd.', '500 thousand €', '560 thousand €']
# ['15/16', 'Aug 13, 2015', 'Everton', 'Oxford United', '500 thousand €', 'Available for free transfer']
# ['14/15', 'Apr 19, 2015', 'Scunthorpe Utd.', 'Everton', '500 thousand €', 'End of loan']
# ['14/15', 'Mar 19, 2015', 'Everton', 'Scunthorpe Utd.', '500 thousand €', 'Loan']
# ['14/15', 'Feb 18, 2015', 'Leyton Orient', 'Everton', '500 thousand €', 'End of loan']
# ['14/15', 'Jan 9, 2015', 'Everton', 'Leyton Orient', '500 thousand €', 'Loan']
# ['14/15', 'Jan 3, 2015', 'Blackpool', 'Everton', '500 thousand €', 'End of loan']
# ['14/15', 'Aug 6, 2014', 'Everton', 'Blackpool', '500 thousand €', 'Loan']
# ['13/14', 'May 31, 2014', 'Leyton Orient', 'Everton', '500 thousand €', 'End of loan']
# ['13/14', 'Mar 27, 2014', 'Everton', 'Leyton Orient', '500 thousand €', 'Loan']
# ['13/14', 'Mar 10, 2014', 'Yeovil Town', 'Everton', '500 thousand €', 'End of loan']
# ['13/14', 'Nov 28, 2013', 'Everton', 'Yeovil Town', '300 thousand €', 'Loan']
# ['12/13', 'May 31, 2013', 'Doncaster', 'Everton', 0, 'End of loan']
# ['12/13', 'Feb 21, 2013', 'Everton', 'Doncaster', 0, 'Loan']
# ['11/12', 'Jul 1, 2011', 'Everton U18', 'Everton', 0, 0]
# 	John Lundstram done
# ['19/20', 'Jul 26, 2019', 'Nottm Forest', 'Sheffield Utd.', '3,00 mil. €', '3,90 mil. €']
# ['13/14', 'Jan 1, 2014', 'Nottingham U18', 'Nottm Forest', 0, 0]
# 	Ben Osborn done
# ['19/20', 'Jul 3, 2019', 'QPR', 'Sheffield Utd.', '3,50 mil. €', '5,60 mil. €']
# ['16/17', 'Jan 30, 2017', 'Bristol City', 'QPR', '400 thousand €', '350 thousand €']
# ['14/15', 'Jul 1, 2014', 'Stevenage', 'Bristol City', '150 thousand €', '?']
# ['11/12', 'Jan 10, 2012', 'Arsenal Res.', 'Stevenage', 0, '?']
# ['11/12', 'Jan 8, 2012', 'Stevenage', 'Arsenal Res.', 0, 'End of loan']
# ['11/12', 'Nov 17, 2011', 'Arsenal Res.', 'Stevenage', 0, 'Loan']
# ['10/11', 'Dec 31, 2010', 'Yeovil Town', 'Arsenal Res.', '250 thousand €', 'End of loan']
# ['10/11', 'Jul 2, 2010', 'Arsenal Res.', 'Yeovil Town', 0, 'Loan']
# ['10/11', 'Jul 1, 2010', 'Arsenal U18', 'Arsenal Res.', 0, 0]
# ['07/08', 'Jan 26, 2008', 'Gillingham U18', 'Arsenal U18', 0, '300 thousand €']
# 	Luke Freeman done
# ['19/20', 'Jul 16, 2019', 'Östersund', 'Sheffield Utd.', '300 thousand €', 'Available for free transfer']
# ['18/19', 'Feb 14, 2019', 'Lazio', 'Östersund', '400 thousand €', '?']
# ['17/18', 'Jun 30, 2018', 'Atlas', 'Lazio', '600 thousand €', 'End of loan']
# ['17/18', 'Aug 31, 2017', 'Lazio', 'Atlas', '350 thousand €', 'Loan']
# ['16/17', 'Jun 30, 2017', 'QPR', 'Lazio', '500 thousand €', 'End of loan']
# ['16/17', 'Jan 31, 2017', 'Lazio', 'QPR', '500 thousand €', 'Loan']
# ['15/16', 'Jul 1, 2015', 'Without Club', 'Lazio', '2,50 mil. €', 0]
# ['14/15', 'Feb 8, 2015', 'West Ham', 'Without Club', '3,50 mil. €', 0]
# ['14/15', 'Dec 16, 2014', 'Cardiff', 'West Ham', '3,50 mil. €', 'End of loan']
# ['14/15', 'Sep 24, 2014', 'West Ham', 'Cardiff', '3,50 mil. €', 'Loan']
# ['13/14', 'Jun 30, 2014', 'QPR', 'West Ham', '4,00 mil. €', 'End of loan']
# ['13/14', 'Feb 19, 2014', 'West Ham', 'QPR', '4,00 mil. €', 'Loan']
# ['12/13', 'Jun 30, 2013', 'Birmingham', 'West Ham', '750 thousand €', 'End of loan']
# ['12/13', 'Aug 6, 2012', 'West Ham', 'Birmingham', '750 thousand €', 'Loan']
# ['11/12', 'Jan 31, 2012', 'Man Utd U18', 'West Ham', 0, '785 thousand €']
# 	Ravel Morrison done
# ['19/20', 'Jul 12, 2019', 'Preston NE', 'Sheffield Utd.', '4,50 mil. €', '7,80 mil. €']
# ['16/17', 'Jul 4, 2016', 'Aston Villa', 'Preston NE', '500 thousand €', 'Available for free transfer']
# ['15/16', 'Jun 30, 2016', 'Preston NE', 'Aston Villa', '500 thousand €', 'End of loan']
# ['15/16', 'Jan 5, 2016', 'Aston Villa', 'Preston NE', '500 thousand €', 'Loan']
# ['15/16', 'Jan 3, 2016', 'Bristol City', 'Aston Villa', '500 thousand €', 'End of loan']
# ['15/16', 'Aug 7, 2015', 'Aston Villa', 'Bristol City', '500 thousand €', 'Loan']
# ['14/15', 'May 11, 2015', 'Preston NE', 'Aston Villa', '250 thousand €', 'End of loan']
# ['14/15', 'Feb 2, 2015', 'Aston Villa', 'Preston NE', '250 thousand €', 'Loan']
# ['14/15', 'Nov 25, 2014', 'Preston NE', 'Aston Villa', '250 thousand €', 'End of loan']
# ['14/15', 'Sep 16, 2014', 'Aston Villa', 'Preston NE', '250 thousand €', 'Loan']
# ['14/15', 'Jul 1, 2014', 'Aston Villa U23', 'Aston Villa', '250 thousand €', 0]
# ['13/14', 'Jul 1, 2013', 'Aston Villa U18', 'Aston Villa U23', 0, 0]
# 	Callum Robinson done
# ['18/19', 'May 4, 2019', 'Gillingham FC', 'Sheffield Utd.', '500 thousand €', 'End of loan']
# ['18/19', 'Jan 31, 2019', 'Sheffield Utd.', 'Gillingham FC', '500 thousand €', 'Loan']
# ['18/19', 'Jan 21, 2019', 'Oxford United', 'Sheffield Utd.', '500 thousand €', 'End of loan']
# ['18/19', 'Aug 9, 2018', 'Sheffield Utd.', 'Oxford United', '500 thousand €', 'Loan']
# ['17/18', 'Jan 15, 2018', 'Charlton', 'Sheffield Utd.', '250 thousand €', '450 thousand €']
# ['16/17', 'Jul 1, 2016', 'Northampt. Town', 'Charlton', '50 thousand €', '?']
# ['14/15', 'Jan 2, 2015', 'Portsmouth', 'Northampt. Town', '50 thousand €', 'Available for free transfer']
# ['13/14', 'Jul 1, 2013', 'Barnet', 'Portsmouth', '50 thousand €', 'Available for free transfer']
# ['10/11', 'Jul 1, 2010', 'Chelmsford City', 'Barnet', 0, 'Available for free transfer']
# ['06/07', 'Jul 1, 2006', 'Chelmsford U19', 'Chelmsford City', 0, 0]
# ['04/05', 'Jul 1, 2004', 'Southend U18', 'Chelmsford U19', 0, 'Available for free transfer']
# 	Ricky Holmes done
# ['19/20', 'Aug 2, 2019', 'Swansea', 'Sheffield Utd.', '8,00 mil. €', '19,10 mil. €']
# ['17/18', 'May 31, 2018', 'Barnsley FC', 'Swansea', '1,00 mil. €', 'End of loan']
# ['17/18', 'Jan 31, 2018', 'Swansea', 'Barnsley FC', '1,00 mil. €', 'Loan']
# ['15/16', 'May 31, 2016', 'Bristol Rovers', 'Swansea', '250 thousand €', 'End of loan']
# ['15/16', 'Mar 7, 2016', 'Swansea', 'Bristol Rovers', '250 thousand €', 'Loan']
# ['15/16', 'Dec 25, 2015', 'Newport County', 'Swansea', '250 thousand €', 'End of loan']
# ['15/16', 'Nov 26, 2015', 'Swansea', 'Newport County', '250 thousand €', 'Loan']
# ['15/16', 'Jul 13, 2015', 'Bradford', 'Swansea', '50 thousand €', '350 thousand €']
# ['14/15', 'May 31, 2015', 'Chester FC', 'Bradford', '50 thousand €', 'End of loan']
# ['14/15', 'Mar 6, 2015', 'Bradford', 'Chester FC', '50 thousand €', 'Loan']
# ['14/15', 'Feb 20, 2015', 'Chester FC', 'Bradford', '50 thousand €', 'End of loan']
# ['14/15', 'Jan 22, 2015', 'Bradford', 'Chester FC', '50 thousand €', 'Loan']
# ['13/14', 'Aug 23, 2013', 'Bradford U18', 'Bradford', 0, 0]
# 	Oliver McBurnie done
# ['19/20', 'Jul 21, 2019', 'Bournemouth', 'Sheffield Utd.', '3,50 mil. €', '11,10 mil. €']
# ['16/17', 'Jul 1, 2016', 'AC Le Havre', 'Bournemouth', '400 thousand €', '6,50 mil. €']
# ['15/16', 'Jul 1, 2015', 'Le Havre B', 'AC Le Havre', '50 thousand €', 0]
# 	Lys Mousset done
# ['15/16', 'Jul 25, 2015', 'Leeds', 'Sheffield Utd.', '1,25 mil. €', '705 thousand €']
# ['14/15', 'Aug 13, 2014', 'Southampton', 'Leeds', '2,00 mil. €', '300 thousand €']
# ['13/14', 'May 31, 2014', 'Doncaster', 'Southampton', '1,80 mil. €', 'End of loan']
# ['13/14', 'Jan 22, 2014', 'Southampton', 'Doncaster', '2,50 mil. €', 'Loan']
# ['13/14', 'Jan 2, 2014', 'Reading', 'Southampton', '3,00 mil. €', 'End of loan']
# ['13/14', 'Sep 26, 2013', 'Southampton', 'Reading', '3,00 mil. €', 'Loan']
# ['12/13', 'May 31, 2013', 'Nottm Forest', 'Southampton', '3,00 mil. €', 'End of loan']
# ['12/13', 'Aug 31, 2012', 'Southampton', 'Nottm Forest', '4,50 mil. €', 'Loan']
# ['11/12', 'Jan 30, 2012', 'Doncaster', 'Southampton', '2,00 mil. €', '2,15 mil. €']
# ['10/11', 'Jul 7, 2010', 'Sheffield Utd.', 'Doncaster', '1,30 mil. €', '1,38 mil. €']
# ['09/10', 'May 31, 2010', 'Doncaster', 'Sheffield Utd.', '1,30 mil. €', 'End of loan']
# ['09/10', 'Sep 1, 2009', 'Sheffield Utd.', 'Doncaster', '1,30 mil. €', 'Loan']
# ['07/08', 'Jul 4, 2007', 'Scunthorpe Utd.', 'Sheffield Utd.', 0, '3,00 mil. €']
# ['05/06', 'Aug 16, 2005', 'Sheffield Utd.', 'Scunthorpe Utd.', 0, '150 thousand €']
# ['04/05', 'May 7, 2005', 'Rush. & Diamon.', 'Sheffield Utd.', 0, 'End of loan']
# ['04/05', 'Jan 21, 2005', 'Sheffield Utd.', 'Rush. & Diamon.', 0, 'Loan']
# ['04/05', 'Jul 1, 2004', 'Sheff Utd U18', 'Sheffield Utd.', 0, 0]
# 	Billy Sharp done
# ['18/19', 'Jul 24, 2018', 'Ipswich', 'Sheffield Utd.', '1,00 mil. €', 'Available for free transfer']
# ['13/14', 'Jul 4, 2013', 'Nottm Forest', 'Ipswich', '500 thousand €', '?']
# ['12/13', 'May 31, 2013', 'Ipswich', 'Nottm Forest', '500 thousand €', 'End of loan']
# ['12/13', 'Jan 4, 2013', 'Nottm Forest', 'Ipswich', '250 thousand €', 'Loan']
# ['12/13', 'Jan 2, 2013', 'Coventry', 'Nottm Forest', '250 thousand €', 'End of loan']
# ['12/13', 'Aug 31, 2012', 'Nottm Forest', 'Coventry', '250 thousand €', 'Loan']
# ['11/12', 'Oct 18, 2011', 'Sheff Wed', 'Nottm Forest', '1,00 mil. €', 'End of loan']
# ['11/12', 'Sep 15, 2011', 'Nottm Forest', 'Sheff Wed', '1,00 mil. €', 'Loan']
# ['09/10', 'Jul 1, 2009', 'Southampton', 'Nottm Forest', '1,50 mil. €', '1,88 mil. €']
# ['07/08', 'Dec 1, 2007', 'Port Vale', 'Southampton', '225 thousand €', 'End of loan']
# ['07/08', 'Aug 1, 2007', 'Southampton', 'Port Vale', '225 thousand €', 'Loan']
# ['06/07', 'Apr 1, 2007', 'Bournemouth', 'Southampton', '50 thousand €', 'End of loan']
# ['06/07', 'Feb 1, 2007', 'Southampton', 'Bournemouth', '50 thousand €', 'Loan']
# ['05/06', 'Oct 1, 2005', 'Notts County', 'Southampton', 0, 'End of loan']
# ['05/06', 'Sep 1, 2005', 'Southampton', 'Notts County', 0, 'Loan']
# ['05/06', 'Jul 1, 2005', 'Notts County', 'Southampton', 0, 'Available for free transfer']
# ['03/04', 'Jul 1, 2003', 'Notts Co. U19', 'Notts County', 0, 0]
# 	David McGoldrick done
# ['18/19', 'May 31, 2019', 'Wigan', 'Sheffield Utd.', '750 thousand €', 'End of loan']
# ['18/19', 'Jan 30, 2019', 'Sheffield Utd.', 'Wigan', '750 thousand €', 'Loan']
# ['16/17', 'Jul 27, 2016', 'Bury', 'Sheffield Utd.', '450 thousand €', '?']
# ['15/16', 'Jul 1, 2015', 'Wolves', 'Bury', '500 thousand €', 'Available for free transfer']
# ['14/15', 'May 31, 2015', 'Wigan', 'Wolves', '500 thousand €', 'End of loan']
# ['14/15', 'Feb 2, 2015', 'Wolves', 'Wigan', '500 thousand €', 'Loan']
# ['13/14', 'Jan 30, 2014', 'Coventry', 'Wolves', '500 thousand €', '?']
# ['12/13', 'Jan 1, 2013', 'Charlton', 'Coventry', '500 thousand €', 'Available for free transfer']
# ['12/13', 'Dec 7, 2012', 'Scunthorpe Utd.', 'Charlton', '500 thousand €', 'End of loan']
# ['12/13', 'Sep 7, 2012', 'Charlton', 'Scunthorpe Utd.', '500 thousand €', 'Loan']
# ['11/12', 'May 31, 2012', 'Crawley Town', 'Charlton', '500 thousand €', 'End of loan']
# ['11/12', 'Mar 17, 2012', 'Charlton', 'Crawley Town', '500 thousand €', 'Loan']
# ['11/12', 'Jan 1, 2012', 'Swindon Town', 'Charlton', '500 thousand €', '?']
# ['11/12', 'Dec 1, 2011', 'Chesterfield FC', 'Swindon Town', '500 thousand €', 'End of loan']
# ['11/12', 'Sep 1, 2011', 'Swindon Town', 'Chesterfield FC', '700 thousand €', 'Loan']
# ['11/12', 'Jul 1, 2011', 'QPR', 'Swindon Town', '700 thousand €', 'Available for free transfer']
# ['10/11', 'May 1, 2011', 'Preston NE', 'QPR', '700 thousand €', '?']
# ['10/11', 'Jan 1, 2011', 'QPR', 'Preston NE', '700 thousand €', 'Available for free transfer']
# ['10/11', 'Jul 1, 2010', 'Sheff Wed', 'QPR', '700 thousand €', 'Available for free transfer']
# ['07/08', 'Jan 1, 2008', 'Southend United', 'Sheff Wed', '700 thousand €', '?']
# ['07/08', 'Aug 1, 2007', 'Sheff Wed', 'Southend United', '700 thousand €', 'Available for free transfer']
# ['06/07', 'Apr 1, 2007', 'Oldham Athletic', 'Sheff Wed', '700 thousand €', '?']
# ['06/07', 'Mar 1, 2007', 'Sheff Wed', 'Oldham Athletic', '700 thousand €', 'Available for free transfer']
# ['06/07', 'Jan 1, 2007', 'Wolves', 'Sheff Wed', '300 thousand €', '650 thousand €']
# ['05/06', 'May 1, 2006', 'Plymouth', 'Wolves', '300 thousand €', '?']
# ['05/06', 'Mar 1, 2006', 'Wolves', 'Plymouth', '50 thousand €', 'Available for free transfer']
# ['05/06', 'Feb 1, 2006', 'QPR', 'Wolves', '50 thousand €', '?']
# ['05/06', 'Jan 1, 2006', 'Wolves', 'QPR', '50 thousand €', 'Available for free transfer']
# ['03/04', 'May 1, 2004', 'Kidderminster', 'Wolves', 0, '?']
# ['03/04', 'Mar 1, 2004', 'Wolves', 'Kidderminster', 0, 'Available for free transfer']
# ['03/04', 'Jul 1, 2003', 'Wolves U18', 'Wolves', 0, 0]
# 	Leon Clarke done

# %%
headers = {'User-Agent': 
           'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}

url = "https://www.transfermarkt.com/bernd-leno/profil/spieler/72476"
page = requests.get(url, headers=headers)
soup = bs(page.content, 'html.parser')

# %%
#scraping transfer page information
TransferColumns = ("season", "date", "left", "joined", "mv", "fee")
TransferRows = pd.DataFrame( {col:[] for col in TransferColumns})
for row in soup.find("div", class_="responsive-table").find("tbody").find_all("tr", class_='zeile-transfer'):
    #try:
    cells = row.find_all( "td")
    cells = list( map( lambda x : x.text.strip(), cells))
    year = cells[0]
    date = cells[1]
    left = cells[5]
    joined = cells[9]
    mv = cells[10]
    fee = cells[11]
    mv = str(mv) if mv != "-" else 0
    fee = str(fee) if fee != "-" else 0
    print(year, date, left, joined, mv, fee)
# Out:
# 18/19 Jul 1, 2018 Bay. Leverkusen Arsenal 20,00 mil. € 25,00 mil. €
# 11/12 Jan 1, 2012 VfB Stuttgart Bay. Leverkusen 5,00 mil. € 10,00 mil. €
# 11/12 Dec 31, 2011 Bay. Leverkusen VfB Stuttgart 5,00 mil. € End of loan
# 11/12 Aug 10, 2011 VfB Stuttgart Bay. Leverkusen 600 thousand € Loan fee:500 thousand €
# 11/12 Jul 1, 2011 Stuttgart II VfB Stuttgart 600 thousand € 0
# 10/11 Jul 1, 2010 Stuttgart U19 Stuttgart II 150 thousand € 0
# 09/10 Jul 1, 2009 Stuttgart U17 Stuttgart U19 0 0
# 07/08 Jul 1, 2007 Stuttgart Yth. Stuttgart U17 0 0
# 03/04 Jul 1, 2003 Bietigheim Yth. Stuttgart Yth. 0 Available for free transfer

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-146567893d0e> in <module>
# ----> 1 for entry in soup.find("table", class_="auflistung").find_all("th"):
#       2     print(entry)
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
